# %%
import json
import random
import numpy as np
from collections import defaultdict
from itertools import combinations
import datetime
import os
import torch
import torch.nn.functional as F
from torch_geometric.data import Data
from torch_geometric.nn import GCNConv
import networkx as nx
import matplotlib.pyplot as plt

# %%
# File paths for data
CARDS_JSON = "data/labeled_cards.json"
DECKS_JSON = "data/one_piece_deck_lists.json"
KNOWN_SYNERGIES_JSON = "graphs/card_synergies.json"

# Load data
with open(CARDS_JSON, "r") as f:
    cards_data = json.load(f)
with open(DECKS_JSON, "r") as f:
    decks_data = json.load(f)
with open(KNOWN_SYNERGIES_JSON, "r") as f:
    known_synergies_data = json.load(f)

print(f"Loaded {len(cards_data)} cards, {len(decks_data)} decks, and synergy data.")
# Out:
# Loaded 1307 cards, 1732 decks, and synergy data.

# %%
# Banned cards list (update as needed)
BANNED_CARDS = {"ST10-001", "OP03-098", "OP05-041", "ST06-015", "OP06-116", "OP02-024", "OP02-052"}

# Card ID to index mapping
card_id_to_index = {c["id"]: i for i, c in enumerate(cards_data)}

# List of leader cards
leaders = [c for c in cards_data if c["type"] == "Leader"]

# Traits, types, and labels for node features
ALL_TRAITS = sorted(set(t for c in cards_data for t in c.get("traits", [])))
trait2idx = {t: i for i, t in enumerate(ALL_TRAITS)}
NUM_TRAITS = len(trait2idx)

ALL_TYPES = sorted(set(c["type"] for c in cards_data))
type2idx = {t: i for i, t in enumerate(ALL_TYPES)}
NUM_TYPES = len(type2idx)

ALL_LABELS = sorted(set(label.strip() for card in cards_data for label in card.get("labels", [])))
label2idx = {label: i for i, label in enumerate(ALL_LABELS)}
NUM_LABELS = len(label2idx)

# %%
def get_card_colors(card):
    """Return a list of colors for the card (leaders may have multiple colors)."""
    ccol = card.get("color", [])
    if isinstance(ccol, str):
        ccol = [ccol]
    return ccol

def find_leader_in_deck(deck):
    """Return the card ID of the leader in the deck, or None if not found."""
    for entry in deck:
        cid = list(entry.keys())[0]
        if any(l["id"] == cid for l in leaders):
            return cid
    return None

def deck_archetype(deck):
    """Return the archetype of the deck's leader, or empty string if not found."""
    lid = find_leader_in_deck(deck)
    if not lid:
        return ""
    leader_card = next((l for l in leaders if l["id"] == lid), None)
    return leader_card.get("archetype", "").strip() if leader_card else ""

def deck_matches_color_archetype(deck, leader_color, leader_arche):
    """Check if the deck's leader matches the specified color and archetype."""
    lid = find_leader_in_deck(deck)
    if not lid:
        return False
    leader_card = next((c for c in cards_data if c["id"] == lid), None)
    if not leader_card:
        return False
    deck_colors = get_card_colors(leader_card)
    deck_arch = leader_card.get("archetype", "").strip().lower()
    if not any(c in deck_colors for c in leader_color):
        return False
    return deck_arch == leader_arche.lower() if leader_arche else True

def gather_decks_for_color_archetype(leader_color, leader_arche, all_decks):
    """Filter decks by leader color and archetype, falling back to color only if no matches."""
    filtered = [d for d in all_decks if deck_matches_color_archetype(d, leader_color, leader_arche)]
    if filtered:
        return filtered
    return [d for d in all_decks if any(c in get_card_colors(next((c for c in cards_data if c["id"] == find_leader_in_deck(d)), {})) for c in leader_color)]

# %%
def multi_hot_trait_vector(card):
    """Create a multi-hot vector for the card's traits."""
    vec = np.zeros(NUM_TRAITS, dtype=np.float32)
    for t in card.get("traits", []):
        if t in trait2idx:
            vec[trait2idx[t]] = 1.0
    return vec

def one_hot_type_vector(card):
    """Create a one-hot vector for the card's type."""
    vec = np.zeros(NUM_TYPES, dtype=np.float32)
    vec[type2idx[card["type"]]] = 1.0
    return vec

def multi_hot_label_vector(card):
    """Create a multi-hot vector for the card's labels."""
    vec = np.zeros(NUM_LABELS, dtype=np.float32)
    for label in card.get("labels", []):
        label = label.strip()
        if label in label2idx:
            vec[label2idx[label]] = 1.0
    return vec

def build_node_feature_with_traits(card, archetype_usage_map):
    """Build a feature vector combining base stats, traits, types, and labels."""
    cost_val = float(card.get("cost", 0))
    ctr_val = float(card.get("counter", 0))
    trait_vec = multi_hot_trait_vector(card)
    type_vec = one_hot_type_vector(card)
    label_vec = multi_hot_label_vector(card)
    base_features = np.array([cost_val, ctr_val], dtype=np.float32)
    return np.concatenate((base_features, trait_vec, type_vec, label_vec))

# %%
def parse_known_synergies(known_synergies_data, synergy_weight=5.0, treat_as_undirected=True):
    """Parse known synergy edges from JSON into a weighted edge dictionary."""
    synergy_edges = defaultdict(float)
    for ln in known_synergies_data.get("links", []):
        src, tgt = ln["source"], ln["target"]
        if src in card_id_to_index and tgt in card_id_to_index:
            synergy_edges[(src, tgt)] += synergy_weight
            if treat_as_undirected:
                synergy_edges[(tgt, src)] += synergy_weight
    return synergy_edges

def build_synergy_graph(relevant_decks, leader_arche, target_colors, synergy_weight=2.0, known_synergy_edges=None):
    """
    Construct a synergy graph from deck co-occurrences and known synergies.
    - Edges from decks are weighted by co-occurrence, boosted if archetype matches.
    - Known synergy edges are added with specified weight.
    """
    G = nx.Graph()
    all_ids = {c["id"] for c in cards_data if any(col in c["color"] for col in target_colors)}
    G.add_nodes_from(all_ids)

    for deck in relevant_decks:
        lid = find_leader_in_deck(deck)
        if not lid:
            continue
        deck_arch = deck_archetype(deck)
        w_factor = synergy_weight if deck_arch.lower() == leader_arche.lower() else 1.0
        deck_cards = [cid for entry in deck for cid, count in entry.items() for _ in range(count) if cid != lid and cid in all_ids]
        for a, b in combinations(deck_cards, 2):
            if a == b:
                continue
            if G.has_edge(a, b):
                G[a][b]["weight"] += w_factor
            else:
                G.add_edge(a, b, weight=w_factor)

    if known_synergy_edges:
        for (src, tgt), w in known_synergy_edges.items():
            if src in all_ids and tgt in all_ids and src not in BANNED_CARDS and tgt not in BANNED_CARDS:
                if G.has_edge(src, tgt):
                    G[src][tgt]["weight"] += w
                else:
                    G.add_edge(src, tgt, weight=w)

    return G

def compute_card_frequency(relevant_decks):
    """Count non-leader card appearances across decks."""
    freq_map = defaultdict(int)
    for d in relevant_decks:
        lid = find_leader_in_deck(d)
        for entry in d:
            cid, cnt = list(entry.items())[0]
            if cid != lid and cnt > 0:
                freq_map[cid] += cnt
    return freq_map

def compute_archetype_usage_ratio(relevant_decks, leader_arche):
    usage_count = {c["id"]: 0 for c in cards_data}
    deck_count = len(relevant_decks)
    arche_decks = [d for d in relevant_decks if deck_archetype(d).lower() == leader_arche.lower()]
    for d in arche_decks:
        lid = find_leader_in_deck(d)
        for cid in {list(entry.keys())[0] for entry in d if list(entry.values())[0] > 0 and list(entry.keys())[0] != lid}:
            usage_count[cid] += 1
    return {c["id"]: usage_count[c["id"]] / deck_count for c in cards_data}

# %%
def build_pyg_data(cards_data, synergy_graph, freq_map, archetype_usage_map):
    """Create a PyG Data object and node labels for GNN training."""
    node_features = [build_node_feature_with_traits(c, archetype_usage_map) for c in cards_data]
    usage_list = [freq_map.get(c["id"], 0) for c in cards_data]
    
    edges, weights = [], []
    for u, v, data in synergy_graph.edges(data=True):
        if u in card_id_to_index and v in card_id_to_index:
            ui, vi = card_id_to_index[u], card_id_to_index[v]
            w = data["weight"]
            edges.extend([[ui, vi], [vi, ui]])
            weights.extend([w, w])
    
    x_tensor = torch.tensor(node_features, dtype=torch.float)
    edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous() if edges else torch.empty((2, 0), dtype=torch.long)
    edge_weight = torch.tensor(weights, dtype=torch.float) if weights else torch.empty((0,), dtype=torch.float)
    
    data_pyg = Data(x=x_tensor, edge_index=edge_index, edge_weight=edge_weight)
    node_labels = np.array(usage_list, dtype=np.float32)
    return data_pyg, node_labels

# %%
class MultiTaskGNN(torch.nn.Module):
    def __init__(self, in_dim, hidden_dim=128, emb_dim=64, dropout=0.5, num_layers=4):
        """
        GNN model predicting node scores and synergy scores.
        - in_dim: Input feature dimension
        - hidden_dim: Hidden layer dimension for GCN
        - emb_dim: Embedding dimension (unused here but kept for flexibility)
        - dropout: Dropout rate
        - num_layers: Number of GCN layers
        """
        super().__init__()
        self.num_layers = num_layers
        self.dropout = torch.nn.Dropout(dropout)
        self.convs = torch.nn.ModuleList([GCNConv(in_dim if i == 0 else hidden_dim, hidden_dim) for i in range(num_layers)])
        self.node_head = torch.nn.Linear(hidden_dim, 1)
        self.synergy_mlp = torch.nn.Sequential(
            torch.nn.Linear(2 * hidden_dim, 128),
            torch.nn.ReLU(),
            torch.nn.Dropout(dropout),
            torch.nn.Linear(128, 64),
            torch.nn.ReLU(),
            torch.nn.Dropout(dropout),
            torch.nn.Linear(64, 32),
            torch.nn.ReLU(),
            torch.nn.Linear(32, 1)
        )

    def forward(self, data):
        """Forward pass to compute node embeddings and scores."""
        x, edge_index = data.x, data.edge_index
        h = x
        for conv in self.convs:
            h = F.relu(self.dropout(conv(h, edge_index)))
        node_score = self.node_head(h).squeeze(-1)
        return h, node_score

    def predict_synergy(self, hu, hv):
        """Predict synergy score between two node embeddings."""
        inp = torch.cat([hu, hv], dim=-1)
        return self.synergy_mlp(inp).squeeze(-1)

# %%
def sample_negative_edges(edge_index, num_nodes, num_neg, cards_data, card_id_to_index):
    """Sample negative edges with shared colors for contrastive learning."""
    existing = {(edge_index[0, i].item(), edge_index[1, i].item()) for i in range(edge_index.shape[1])}
    neg = []
    attempts = 0
    while len(neg) < num_neg and attempts < 500000:
        attempts += 1
        a_idx, b_idx = random.randint(0, num_nodes - 1), random.randint(0, num_nodes - 1)
        if a_idx == b_idx or (a_idx, b_idx) in existing:
            continue
        a_colors = set(get_card_colors(cards_data[a_idx]))
        b_colors = set(get_card_colors(cards_data[b_idx]))
        if a_colors & b_colors:
            neg.append((a_idx, b_idx))
    return neg

def train_gnn(model, data, node_labels_np, epochs=300, lr=0.005, neg_factor=2.0, synergy_loss_weight=2.0):
    """
    Train the GNN with node score and synergy prediction tasks.
    - synergy_loss_weight: Adjusts the influence of synergy loss (increase if synergies are underlearned).
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    data = data.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=1e-4)
    
    mean_val = node_labels_np.mean()
    std_val = max(node_labels_np.std(), 1e-9)
    node_labels_norm = (node_labels_np - mean_val) / std_val
    node_labels_t = torch.tensor(node_labels_norm, dtype=torch.float, device=device)
    
    best_loss = float('inf')
    patience, no_improve = 20, 0
    
    for epoch in range(epochs):
        model.train()
        optimizer.zero_grad()
        node_emb, node_score = model(data)
        loss_node = F.mse_loss(node_score, node_labels_t)
        
        pos_u, pos_v, pos_w = [], [], []
        for i in range(0, data.edge_index.shape[1], 2):
            u, v, w = data.edge_index[0, i].item(), data.edge_index[1, i].item(), data.edge_weight[i].item()
            pos_u.append(u)
            pos_v.append(v)
            pos_w.append(np.log1p(w))
        
        loss_synergy = 0.0
        if pos_u:
            pos_u_t = torch.tensor(pos_u, dtype=torch.long, device=device)
            pos_v_t = torch.tensor(pos_v, dtype=torch.long, device=device)
            pos_w_t = torch.tensor(pos_w, dtype=torch.float, device=device)
            num_neg = int(len(pos_u) * neg_factor)
            neg_edges = sample_negative_edges(data.edge_index, data.x.shape[0], num_neg, cards_data, card_id_to_index)
            neg_u = torch.tensor([e[0] for e in neg_edges], dtype=torch.long, device=device)
            neg_v = torch.tensor([e[1] for e in neg_edges], dtype=torch.long, device=device)
            neg_w_t = torch.zeros(len(neg_edges), dtype=torch.float, device=device)
            all_u = torch.cat([pos_u_t, neg_u])
            all_v = torch.cat([pos_v_t, neg_v])
            all_w = torch.cat([pos_w_t, neg_w_t])
            hu, hv = node_emb[all_u], node_emb[all_v]
            synergy_pred = model.predict_synergy(hu, hv)
            loss_synergy = F.mse_loss(synergy_pred, all_w)
        
        loss = loss_node + synergy_loss_weight * loss_synergy
        loss.backward()
        optimizer.step()
        
        if loss.item() < best_loss:
            best_loss = loss.item()
            no_improve = 0
        else:
            no_improve += 1
        
        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1}/{epochs} - Node Loss: {loss_node.item():.4f}, Synergy Loss: {loss_synergy:.4f}, Total: {loss.item():.4f}")
        
        if no_improve >= patience:
            print(f"Early stopping at epoch {epoch+1}")
            break
    
    return model, mean_val, std_val

# %%
def build_synergy_matrix(model, data, freq_map, node_labels_np, mean_val, std_val):
    """
    Generate a synergy matrix and rescaled node scores.
    - Diagonal entries are set to node scores (minimum 0.1).
    - Off-diagonal entries are synergy predictions.
    """
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    data = data.to(device)
    with torch.no_grad():
        node_emb, node_score_t = model(data)
    node_emb = node_emb.cpu()
    node_score = node_score_t.cpu().numpy() * std_val + mean_val
    for i, c in enumerate(cards_data):
        if freq_map.get(c["id"], 0) == 0:
            node_score[i] -= 2.0  # Penalty for unused cards
    
    num_cards = len(cards_data)
    synergy_matrix = np.zeros((num_cards, num_cards), dtype=np.float32)
    for i in range(num_cards):
        hi = node_emb[i].unsqueeze(0).to(device)
        hj = node_emb.to(device)
        synergies = model.predict_synergy(hi.expand(num_cards, -1), hj).detach().cpu().numpy()
        synergy_matrix[i, :] = synergies
        synergy_matrix[:, i] = synergies  # Ensure symmetry
        synergy_matrix[i, i] = max(0.1, node_score[i])
    
    return synergy_matrix, node_score

# %%
def save_model(model, filename):
    """Save the model state, archiving existing files with timestamps."""
    models_dir = "models"
    archive_dir = os.path.join(models_dir, "archive")
    os.makedirs(models_dir, exist_ok=True)
    file_path = os.path.join(models_dir, filename)
    if os.path.exists(file_path):
        os.makedirs(archive_dir, exist_ok=True)
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        os.rename(file_path, os.path.join(archive_dir, f"{timestamp}_{filename}"))
        print(f"Existing model archived to: {timestamp}_{filename}")
    torch.save(model.state_dict(), file_path)
    print(f"Model saved to: {file_path}")

def load_model(model, filepath):
    """Load the model state from filepath."""
    if os.path.exists(filepath):
        model.load_state_dict(torch.load(filepath))
        print(f"Model loaded from: {filepath}")
    else:
        print(f"Model file not found: {filepath}")
    return model

# %%
def train_and_build_synergy_per_leader(target_leader_id):
    """
    Train the GNN and build synergy matrix for a specific leader.
    - Filters decks by leader color and archetype.
    - Falls back to all decks if no matches are found.
    """
    leader_card = next((c for c in leaders if c["id"] == target_leader_id), None)
    if not leader_card:
        raise ValueError(f"Leader ID {target_leader_id} not found!")
    
    leader_color = get_card_colors(leader_card)
    leader_arche = leader_card.get("archetype", "").strip()
    relevant_decks = gather_decks_for_color_archetype(leader_color, leader_arche, decks_data) or decks_data
    
    known_synergy_edges = parse_known_synergies(known_synergies_data, synergy_weight=5.0)
    synergy_graph = build_synergy_graph(relevant_decks, leader_arche, leader_color, synergy_weight=2.0, known_synergy_edges=known_synergy_edges)
    freq_map = compute_card_frequency(relevant_decks)
    archetype_usage_map = compute_archetype_usage_ratio(relevant_decks, leader_arche)
    
    data_pyg, node_labels_np = build_pyg_data(cards_data, synergy_graph, freq_map, archetype_usage_map)
    in_dim = data_pyg.x.shape[1]
    model = MultiTaskGNN(in_dim=in_dim, hidden_dim=128, emb_dim=64, dropout=0.5, num_layers=4)
    model, mean_val, std_val = train_gnn(model, data_pyg, node_labels_np, epochs=300, lr=0.005, neg_factor=2.0, synergy_loss_weight=2.0)
    save_model(model, f"gnn_model_{target_leader_id}.pth")
    
    synergy_matrix, node_score = build_synergy_matrix(model, data_pyg, freq_map, node_labels_np, mean_val, std_val)
    return synergy_matrix, node_score, relevant_decks

# %%
def evaluate_synergy_prediction_accuracy(model, data, known_synergy_data):
    """Evaluate synergy prediction accuracy using MSE on known synergy edges."""
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    data = data.to(device)
    with torch.no_grad():
        node_emb, _ = model(data)
    preds, actuals = [], []
    for (src, tgt), w in known_synergy_data.items():
        if src in card_id_to_index and tgt in card_id_to_index:
            i, j = card_id_to_index[src], card_id_to_index[tgt]
            pred = model.predict_synergy(node_emb[i].unsqueeze(0), node_emb[j].unsqueeze(0)).item()
            preds.append(pred)
            actuals.append(np.log1p(w))
    if not preds:
        print("No known synergy edges found for evaluation.")
        return
    mse = np.mean((np.array(preds) - np.array(actuals))**2)
    print(f"Synergy Prediction MSE on Known Edges: {mse:.4f}")

    return mse

def evaluate_deck(deck, synergy_matrix, node_score, singleton_penalty=10.0, max_singleton_ratio=0.3):
    """Evaluate deck quality with node scores, synergy scores, and singleton penalty."""
    deck_arr = np.array(deck, dtype=np.float32)
    total_score = np.dot(node_score, deck_arr)
    synergy_total = 0.5 * (deck_arr @ synergy_matrix @ deck_arr - np.sum(deck_arr**2 * np.diag(synergy_matrix)))
    base_score = total_score + synergy_total
    total_copies = deck_arr.sum()
    num_singletons = np.sum(deck_arr == 1)
    ratio = num_singletons / total_copies if total_copies > 0 else 0
    penalty = singleton_penalty * (ratio - max_singleton_ratio) * total_copies if ratio > max_singleton_ratio else 0
    return base_score - penalty

def greedy_initial_deck(valid_indices, node_score, deck_size, max_copies):
    """Initialize a deck greedily based on node scores."""
    deck = [0] * len(cards_data)
    sorted_indices = sorted(valid_indices, key=lambda i: node_score[i], reverse=True)
    remaining = deck_size
    for i in sorted_indices:
        copies = min(max_copies, remaining)
        deck[i] = copies
        remaining -= copies
        if remaining <= 0:
            break
    return deck

def local_search_deck(current_deck, synergy_matrix, node_score, iterations=1000000,
                      singleton_penalty=20.0, max_singleton_ratio=0.2, deck_size=50,
                      max_copies=4, valid_indices=None, early_stop=500):
    """
    Refine the deck using local search with early stopping and bias toward redundancy.
    
    Args:
        current_deck: List of card counts (length = number of cards in pool).
        synergy_matrix: Matrix of pairwise synergies between cards.
        node_score: Array of individual card scores.
        iterations: Maximum number of iterations.
        singleton_penalty: Penalty per singleton (increased to 20.0).
        max_singleton_ratio: Max fraction of deck that can be singletons (lowered to 0.2).
        deck_size: Total number of cards in deck (default 50).
        max_copies: Maximum copies per card (default 4).
        valid_indices: List of indices for valid cards (e.g., matching leader color).
        early_stop: Stop if no improvement after this many iterations.
    
    Returns:
        Optimized deck as a list of card counts.
    """
    # Initialize best deck and score
    best_deck = current_deck[:]
    best_score = evaluate_deck(best_deck, synergy_matrix, node_score, singleton_penalty, max_singleton_ratio)
    current_deck = best_deck[:]
    no_improve = 0
    
    # Precompute valid indices if not provided
    if valid_indices is None:
        valid_indices = list(range(len(current_deck)))
    
    for it in range(iterations):
        neighbor = current_deck[:]
        # Get cards currently in the deck
        nonzero = [i for i, count in enumerate(neighbor) if count > 0]
        if not nonzero:
            continue
        
        # Remove one card
        remove_idx = random.choice(nonzero)
        neighbor[remove_idx] -= 1
        
        # Decide whether to add to an existing card or a new one
        existing_cards = [i for i in nonzero if neighbor[i] < max_copies]
        new_cards = [i for i in valid_indices if neighbor[i] == 0]
        
        # Bias toward adding to existing cards (70% chance if possible)
        if existing_cards and (not new_cards or random.random() < 0.7):
            add_idx = random.choice(existing_cards)
        elif new_cards:
            add_idx = random.choice(new_cards)
        else:
            continue  # No valid move possible
        
        neighbor[add_idx] += 1
        
        # Ensure deck size constraint
        if sum(neighbor) != deck_size:
            continue
        
        # Evaluate the new deck
        neighbor_score = evaluate_deck(neighbor, synergy_matrix, node_score, singleton_penalty, max_singleton_ratio)
        
        # Accept move if it improves the score or occasionally for exploration
        if neighbor_score > best_score or random.random() < 0.05:
            current_deck = neighbor[:]
            if neighbor_score > best_score:
                best_score = neighbor_score
                best_deck = neighbor[:]
                no_improve = 0
                if (it + 1) % 10000 == 0:  # Less frequent logging
                    print(f"Iteration {it+1}: Improved score to {best_score:.2f}")
            else:
                no_improve += 1
        else:
            no_improve += 1
        
        # Early stopping
        if no_improve >= early_stop:
            print(f"Early stopping at iteration {it+1}, Best Score: {best_score:.2f}")
            break
    
    return best_deck

def build_deck_local_search(target_leader_id, synergy_matrix, node_score, deck_size=50,
                            max_copies=4, iterations=1000000, singleton_penalty=20.0,
                            max_singleton_ratio=0.2):
    """Build a deck using local search, filtering cards by leader color."""
    leader_card = next((c for c in cards_data if c["id"] == target_leader_id), None)
    if not leader_card:
        raise ValueError(f"Leader {target_leader_id} not found")
    leader_color = set(get_card_colors(leader_card))
    valid_indices = [i for i, card in enumerate(cards_data) if card["id"] not in BANNED_CARDS and card["type"] != "Leader" and leader_color & set(get_card_colors(card))]
    
    initial_deck = greedy_initial_deck(valid_indices, node_score, deck_size, max_copies)
    return local_search_deck(initial_deck, synergy_matrix, node_score, iterations, singleton_penalty, max_singleton_ratio, deck_size, max_copies, valid_indices)

# %%
def print_deck_list(deck, leader_id):
    """Print the deck in a human-readable format."""
    leader_card = next((c for c in cards_data if c["id"] == leader_id), None)
    print(f"=== DECK for Leader {leader_id} ({leader_card.get('name', 'Unknown')}) ===")
    total = 0
    for i, copies in enumerate(deck):
        if copies > 0:
            cid, name = cards_data[i]["id"], cards_data[i]["name"]
            print(f"{copies}x {cid} - {name}")
            total += copies
    print(f"Total non-leader cards: {total}")

def evaluate_deck_vs_meta(deck, relevant_decks):
    """Compare deck card usage to the meta."""
    meta_freq = compute_card_frequency(relevant_decks)
    deck_freq_map = {cards_data[i]["id"]: copies for i, copies in enumerate(deck) if copies > 0}
    sorted_meta = sorted(meta_freq.items(), key=lambda x: x[1], reverse=True)[:10]
    print("Top 10 cards in meta (by usage):")
    for cid, freq in sorted_meta:
        nm = next((c["name"] for c in cards_data if c["id"] == cid), cid)
        print(f"{cid} - {nm}: {freq}")
    overlap = len(set(deck_freq_map.keys()) & {cid for cid, _ in sorted_meta})
    print(f"Deck shares {overlap} of the meta's top 10 cards.")

def synergy_heatmap(deck, synergy_matrix, diagonal= 1.0, title="Deck Synergy Heatmap"):
    """Plot a heatmap of synergy scores among deck cards."""
    deck_idxs = [i for i, cpy in enumerate(deck) if cpy > 0]
    if not deck_idxs:
        print("No cards in deck to visualize.")
        return
    sub_matrix = synergy_matrix[np.ix_(deck_idxs, deck_idxs)]
    np.fill_diagonal(sub_matrix, diagonal)
    plt.figure(figsize=(8, 6))
    plt.imshow(sub_matrix, aspect='auto', origin='upper', interpolation='nearest')
    plt.colorbar()
    plt.title(title)
    plt.xlabel("Card Index in Deck")
    plt.ylabel("Card Index in Deck")
    plt.show()

def inspect_synergy_predictions(deck, synergy_matrix):
    """Inspect top and bottom synergy predictions for deck cards."""
    for i, copies in enumerate(deck):
        if copies > 0:
            name = cards_data[i]["name"]
            best_synergy = np.argsort(synergy_matrix[i])[::-1]
            print(f"Top 3 cards with highest synergy for {name}:")
            count = 0
            for j in best_synergy:
                if deck[j] == 0:
                    print(f"{cards_data[j]['name']} - Synergy: {synergy_matrix[i, j]:.2f}")
                    count += 1
                    if count == 3:
                        break
            print(f"Top 3 cards with lowest synergy for {name}:")
            count = 0
            for j in np.argsort(synergy_matrix[i]):
                if deck[j] == 0:
                    print(f"{cards_data[j]['name']} - Synergy: {synergy_matrix[i, j]:.2f}")
                    count += 1
                    if count == 3:
                        break
            print()

def generate_deck_graph(deck, synergy_matrix, title="Deck Graph", ):
    """uses cards as nodes and predicted synergy as edges to create a graph"""
    G = nx.Graph()
    for i, copies in enumerate(deck):
        if copies > 0:
            G.add_node(cards_data[i]["name"])
    for i, copies in enumerate(deck):
        if copies > 0:
            for j, copies2 in enumerate(deck):
                if copies2 > 0:
                    G.add_edge(cards_data[i]["name"], cards_data[j]["name"], weight=synergy_matrix[i, j])
    plt.figure(figsize=(12, 12))
    pos = nx.spring_layout(G)
    edge_labels = nx.get_edge_attributes(G, 'weight')
    nx.draw(G, pos, with_labels=True, node_size=5000, node_color='skyblue', font_size=10, font_weight='bold')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
    plt.title(title)
    plt.show()

# %%
# Define target leader
target_leader_id = "OP01-001"  # Roronoa Zoro

# %%
# print("Training GNN and Building Synergy Matrix...")
synergy_matrix, node_score, relevant_decks = train_and_build_synergy_per_leader(target_leader_id)
# Out:
# Epoch 10/300 - Node Loss: 36.0257, Synergy Loss: 2.6524, Total: 41.3305
# Epoch 20/300 - Node Loss: 4.3257, Synergy Loss: 2.5172, Total: 9.3602
# Epoch 30/300 - Node Loss: 1.6228, Synergy Loss: 2.3075, Total: 6.2379
# Epoch 40/300 - Node Loss: 1.0628, Synergy Loss: 2.1740, Total: 5.4109
# Epoch 50/300 - Node Loss: 1.0170, Synergy Loss: 2.0943, Total: 5.2055
# Epoch 60/300 - Node Loss: 1.0271, Synergy Loss: 2.0474, Total: 5.1219
# Epoch 70/300 - Node Loss: 1.0962, Synergy Loss: 1.9333, Total: 4.9627
# Epoch 80/300 - Node Loss: 1.1885, Synergy Loss: 1.7075, Total: 4.6036
# Epoch 90/300 - Node Loss: 1.2314, Synergy Loss: 1.3183, Total: 3.8679
# Epoch 100/300 - Node Loss: 1.3644, Synergy Loss: 1.1650, Total: 3.6945
# Epoch 110/300 - Node Loss: 1.2251, Synergy Loss: 1.1142, Total: 3.4534
# Epoch 120/300 - Node Loss: 1.3095, Synergy Loss: 1.0818, Total: 3.4731
# Epoch 130/300 - Node Loss: 1.2297, Synergy Loss: 1.0459, Total: 3.3214
# Epoch 140/300 - Node Loss: 1.2048, Synergy Loss: 0.9556, Total: 3.1161
# Epoch 150/300 - Node Loss: 1.2128, Synergy Loss: 0.9012, Total: 3.0151
# Epoch 160/300 - Node Loss: 1.1422, Synergy Loss: 0.8651, Total: 2.8723
# Epoch 170/300 - Node Loss: 1.1752, Synergy Loss: 0.8564, Total: 2.8881
# Epoch 180/300 - Node Loss: 1.1887, Synergy Loss: 0.8295, Total: 2.8476
# Epoch 190/300 - Node Loss: 1.1947, Synergy Loss: 0.7214, Total: 2.6374
# Epoch 200/300 - Node Loss: 1.2335, Synergy Loss: 0.6799, Total: 2.5933
# Epoch 210/300 - Node Loss: 1.2225, Synergy Loss: 0.7305, Total: 2.6835
# Epoch 220/300 - Node Loss: 1.1987, Synergy Loss: 0.6689, Total: 2.5364
# Epoch 230/300 - Node Loss: 1.1495, Synergy Loss: 0.6582, Total: 2.4658
# Early stopping at epoch 233
# Existing model archived to: 20250310_014559_gnn_model_OP01-001.pth
# Model saved to: models\gnn_model_OP01-001.pth

# %%
print("\nBuilding Deck with Local Search...")
best_deck = build_deck_local_search(target_leader_id, synergy_matrix, node_score,
                                    deck_size=50, max_copies=4, iterations=100000, max_singleton_ratio=0.1)
# Out:
# Building Deck with Local Search...
# Early stopping at iteration 574, Best Score: 3546.44

# %%
# Evaluate and visualize
print("\nDeck List:")
print_deck_list(best_deck, target_leader_id)
# Out:
# Deck List:
# === DECK for Leader OP01-001 (Roronoa Zoro) ===
# 3x OP01-026 - Gum-Gum Red Hawk
# 3x OP01-029 - Radical Beam!!
# 2x OP01-017 - Nico Robin
# 3x ST01-014 - Guard Point
# 3x ST01-006 - Tony Tony Chopper
# 2x ST01-004 - Sanji
# 3x ST01-007 - Nami
# 2x OP02-004 - Edward Newgate
# 2x OP02-005 - Curly Dadan
# 3x OP02-015 - Makino
# 3x OP02-016 - Magra
# 3x P-013 - Gordon
# 3x P-014 - Koby
# 3x P-019 - Bepo
# 3x OP03-018 - Fire Fist
# 3x OP03-019 - Fiery Doll
# 3x OP04-016 - Bad Manners Kick Course
# 1x OP05-010 - Nico Robin
# 2x OP05-011 - Bartholomew Kuma
# Total non-leader cards: 50

# %%
print("\nEvaluating Deck vs. Meta:")
evaluate_deck_vs_meta(best_deck, relevant_decks)
# Out:
# Evaluating Deck vs. Meta:
# Top 10 cards in meta (by usage):
# OP01-025 - Roronoa Zoro: 524
# OP01-006 - Otama: 492
# OP02-015 - Makino: 458
# OP02-005 - Curly Dadan: 452
# OP01-016 - Nami: 421
# ST01-011 - Brook: 327
# OP03-013 - Marco: 301
# OP03-008 - Buggy: 295
# ST01-015 - Jet Pistol: 292
# OP02-016 - Magra: 292
# Deck shares 3 of the meta's top 10 cards.

# %%
print("\nSynergy Heatmap:")
synergy_heatmap(best_deck, synergy_matrix, diagonal=2.7)
# Out:
# Synergy Heatmap:

# %%
print("\nInspecting Synergy Predictions:")
inspect_synergy_predictions(best_deck, synergy_matrix)
# Out:
# Inspecting Synergy Predictions:
# Top 3 cards with highest synergy for Gum-Gum Red Hawk:
# In 2 years!!! To Sabaody - Synergy: 2.81
# Buggy - Synergy: 2.79
# Mr. Tanaka - Synergy: 2.79
# Top 3 cards with lowest synergy for Gum-Gum Red Hawk:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Radical Beam!!:
# In 2 years!!! To Sabaody - Synergy: 2.81
# Nami - Synergy: 2.81
# Striker - Synergy: 2.80
# Top 3 cards with lowest synergy for Radical Beam!!:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.25
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Nico Robin:
# In 2 years!!! To Sabaody - Synergy: 2.80
# Nami - Synergy: 2.80
# Carrot - Synergy: 2.80
# Top 3 cards with lowest synergy for Nico Robin:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Guard Point:
# In 2 years!!! To Sabaody - Synergy: 2.81
# Nami - Synergy: 2.81
# Carrot - Synergy: 2.81
# Top 3 cards with lowest synergy for Guard Point:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Tony Tony Chopper:
# In 2 years!!! To Sabaody - Synergy: 2.81
# Trafalgar Law - Synergy: 2.81
# Nami - Synergy: 2.81
# Top 3 cards with lowest synergy for Tony Tony Chopper:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Sanji:
# In 2 years!!! To Sabaody - Synergy: 2.80
# Carrot - Synergy: 2.80
# Jinbe - Synergy: 2.80
# Top 3 cards with lowest synergy for Sanji:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Nami:
# In 2 years!!! To Sabaody - Synergy: 2.81
# Jinbe - Synergy: 2.81
# Carrot - Synergy: 2.81
# Top 3 cards with lowest synergy for Nami:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Edward Newgate:
# In 2 years!!! To Sabaody - Synergy: 2.81
# Nami - Synergy: 2.81
# Trafalgar Law - Synergy: 2.81
# Top 3 cards with lowest synergy for Edward Newgate:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Curly Dadan:
# In 2 years!!! To Sabaody - Synergy: 2.81
# Usopp - Synergy: 2.81
# Jinbe - Synergy: 2.81
# Top 3 cards with lowest synergy for Curly Dadan:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Makino:
# In 2 years!!! To Sabaody - Synergy: 2.81
# Dogura - Synergy: 2.81
# Carrot - Synergy: 2.81
# Top 3 cards with lowest synergy for Makino:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Magra:
# In 2 years!!! To Sabaody - Synergy: 2.81
# Dogura - Synergy: 2.81
# Carrot - Synergy: 2.81
# Top 3 cards with lowest synergy for Magra:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Gordon:
# In 2 years!!! To Sabaody - Synergy: 2.81
# Jinbe - Synergy: 2.81
# Usopp - Synergy: 2.81
# Top 3 cards with lowest synergy for Gordon:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Koby:
# Striker - Synergy: 2.82
# In 2 years!!! To Sabaody - Synergy: 2.82
# Buggy - Synergy: 2.82
# Top 3 cards with lowest synergy for Koby:
# Sakazuki - Synergy: 0.25
# Three Sword Style: Oni Giri - Synergy: 0.25
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Bepo:
# In 2 years!!! To Sabaody - Synergy: 2.79
# Moby Dick - Synergy: 2.79
# Jinbe - Synergy: 2.79
# Top 3 cards with lowest synergy for Bepo:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Fire Fist:
# In 2 years!!! To Sabaody - Synergy: 2.81
# Buggy - Synergy: 2.81
# Moby Dick - Synergy: 2.81
# Top 3 cards with lowest synergy for Fire Fist:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Fiery Doll:
# In 2 years!!! To Sabaody - Synergy: 2.78
# Buggy - Synergy: 2.78
# Marco - Synergy: 2.78
# Top 3 cards with lowest synergy for Fiery Doll:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.24
#
# Top 3 cards with highest synergy for Bad Manners Kick Course:
# In 2 years!!! To Sabaody - Synergy: 2.81
# Buggy - Synergy: 2.81
# Kung-Fu Dugong - Synergy: 2.81
# Top 3 cards with lowest synergy for Bad Manners Kick Course:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.25
#
# Top 3 cards with highest synergy for Nico Robin:
# In 2 years!!! To Sabaody - Synergy: 2.78
# Buggy - Synergy: 2.78
# Tony Tony Chopper - Synergy: 2.78
# Top 3 cards with lowest synergy for Nico Robin:
# Sakazuki - Synergy: 0.24
# Three Sword Style: Oni Giri - Synergy: 0.24
# King - Synergy: 0.24
#
# Top 3 cards with highest synergy for Bartholomew Kuma:
# In 2 years!!! To Sabaody - Synergy: 2.82
# Buggy - Synergy: 2.82
# Chess - Synergy: 2.82
# Top 3 cards with lowest synergy for Bartholomew Kuma:
# Sakazuki - Synergy: 0.25
# Three Sword Style: Oni Giri - Synergy: 0.25
# King - Synergy: 0.25

# %%
generate_deck_graph(best_deck, synergy_matrix)

# %%
evaluation_dir = "evaluations"
os.makedirs(evaluation_dir, exist_ok=True)

# %%
# Number of trials per leader
num_trials = 20

# Number of deck samples for evaluation
num_deck_trials = 250

# List of selected leaders for evaluation
selected_leader_ids = [
    # "OP01-001", # Roronoa Zoro Aggro
    "ST02-001", # Eustass Kid Midrange
    "ST13-003", # Monkey D. Luffy Combo
    "OP07-079", # Lucci Control
    "OP08-098" # Kalgara OP08
    ]

selected_leaders = []
for leader_id in selected_leader_ids:
    leader = next((l for l in leaders if l["id"] == leader_id), None)
    if leader:
        selected_leaders.append(leader)
        print(f"Confirmed leader: {leader_id} ({leader['name']}) - {leader.get('archetype', 'Unknown')}")
    else:
        print(f"Warning: Leader {leader_id} not found in cards_data!")
# Out:
# Confirmed leader: ST02-001 (Eustass Captain Kid) - Midrange
# Confirmed leader: ST13-003 (Monkey.D.Luffy) - Combo
# Confirmed leader: OP07-079 (Rob Lucci) - Control
# Confirmed leader: OP08-098 (Kalgara) - Midrange

# %%
# Run evaluations for each selected leader
for leader in selected_leaders:
    leader_id = leader["id"]
    leader_dir = os.path.join(evaluation_dir, leader_id)
    os.makedirs(leader_dir, exist_ok=True)
    
    print(f"\n=== Evaluating Leader: {leader_id} ({leader['name']}) ===")
    
    # Gather relevant decks once per leader (to avoid recomputing unnecessarily)
    leader_color = get_card_colors(leader)
    leader_arche = leader.get("archetype", "").strip()
    relevant_decks = gather_decks_for_color_archetype(leader_color, leader_arche, decks_data) or decks_data
    
    # Run multiple GNN training trials
    all_trial_results = []
    for trial in range(1, num_trials + 1):
        print(f"\nGNN Trial {trial}/{num_trials}")
        
        # Train GNN and build synergy matrix for this trial
        print("Training GNN and building synergy matrix...")
        synergy_matrix, node_score, _ = train_and_build_synergy_per_leader(leader_id)
        
        # Generate multiple deck samples for this model
        deck_results = []
        for deck_trial in range(1, num_deck_trials + 1):
            if deck_trial % 100 == 0:  # Progress update
                print(f"  Deck Trial {deck_trial}/{num_deck_trials}")
            
            # Build deck using local search
            best_deck = build_deck_local_search(
                leader_id, synergy_matrix, node_score,
                deck_size=50, max_copies=4, iterations=100000,
                singleton_penalty=20.0, max_singleton_ratio=0.1
            )
            
            # Evaluate deck score
            deck_score = evaluate_deck(best_deck, synergy_matrix, node_score, singleton_penalty=20.0, max_singleton_ratio=0.1)
            
            # Compare to meta (UF2)
            meta_overlap = None
            if relevant_decks:
                meta_freq = compute_card_frequency(relevant_decks)
                sorted_meta = sorted(meta_freq.items(), key=lambda x: x[1], reverse=True)[:10]
                deck_cards = [cards_data[i]["id"] for i, copies in enumerate(best_deck) if copies > 0]
                meta_top_cards = {cid for cid, _ in sorted_meta}
                meta_overlap = len(set(deck_cards) & meta_top_cards)
            
            # Calculate heuristic indicators (UF3)
            deck_idxs = [i for i, copies in enumerate(best_deck) if copies > 0]
            avg_synergy = 0.0
            if len(deck_idxs) > 1:
                synergies = [synergy_matrix[i, j] for i in deck_idxs for j in deck_idxs if i < j]
                avg_synergy = np.mean(synergies) if synergies else 0.0
            num_singletons = sum(1 for copies in best_deck if copies == 1)
            
            # Store deck trial data
            deck_data = {
                "deck_trial": deck_trial,
                "deck": {cards_data[i]["id"]: int(copies) for i, copies in enumerate(best_deck) if copies > 0},
                "score": float(deck_score),
                "meta_overlap": meta_overlap,
                "avg_synergy": float(avg_synergy),
                "num_singletons": int(num_singletons)
            }
            deck_results.append(deck_data)
        
        # Store GNN trial data
        trial_data = {
            "gnn_trial": trial,
            "deck_results": deck_results
        }
        all_trial_results.append(trial_data)
        
        # Save individual GNN trial result
        with open(os.path.join(leader_dir, f"gnn_trial_{trial}.json"), "w") as f:
            json.dump(trial_data, f, indent=2)
        
        print(f"GNN Trial {trial} completed with {num_deck_trials} decks.")
    
    # Save all trials in one file per leader
    with open(os.path.join(leader_dir, "all_trials.json"), "w") as f:
        json.dump(all_trial_results, f, indent=2)
    
    print(f"Evaluations for {leader_id} completed. Results saved in {leader_dir}")

print("\nAll evaluations completed. Results are stored in the 'evaluations' directory.")
# Out:
# === Evaluating Leader: ST02-001 (Eustass Captain Kid) ===
#
# GNN Trial 1/20
# Training GNN and building synergy matrix...
# Epoch 10/300 - Node Loss: 8.8250, Synergy Loss: 2.5795, Total: 13.9841
# Epoch 20/300 - Node Loss: 2.8081, Synergy Loss: 2.4369, Total: 7.6818
# Epoch 30/300 - Node Loss: 1.3433, Synergy Loss: 2.3109, Total: 5.9651
# Epoch 40/300 - Node Loss: 1.0433, Synergy Loss: 2.2083, Total: 5.4598
# Epoch 50/300 - Node Loss: 1.0029, Synergy Loss: 2.1166, Total: 5.2360
# Epoch 60/300 - Node Loss: 1.0026, Synergy Loss: 2.0307, Total: 5.0641
# Epoch 70/300 - Node Loss: 1.0025, Synergy Loss: 1.9524, Total: 4.9072
# Epoch 80/300 - Node Loss: 1.0045, Synergy Loss: 1.8828, Total: 4.7701
# Epoch 90/300 - Node Loss: 1.0674, Synergy Loss: 1.7975, Total: 4.6624
# Epoch 100/300 - Node Loss: 1.0853, Synergy Loss: 1.6945, Total: 4.4743
# Epoch 110/300 - Node Loss: 1.0963, Synergy Loss: 1.4890, Total: 4.0743
# Epoch 120/300 - Node Loss: 1.3303, Synergy Loss: 1.1660, Total: 3.6623
# Epoch 130/300 - Node Loss: 1.1661, Synergy Loss: 1.0244, Total: 3.2149
# Epoch 140/300 - Node Loss: 1.1685, Synergy Loss: 0.9780, Total: 3.1246
# Epoch 150/300 - Node Loss: 1.1677, Synergy Loss: 0.8836, Total: 2.9349
# Epoch 160/300 - Node Loss: 1.1477, Synergy Loss: 0.8275, Total: 2.8028
# Epoch 170/300 - Node Loss: 1.1347, Synergy Loss: 0.7755, Total: 2.6857
# Epoch 180/300 - Node Loss: 1.1423, Synergy Loss: 0.7148, Total: 2.5719
# Epoch 190/300 - Node Loss: 1.1476, Synergy Loss: 0.6834, Total: 2.5145
# Epoch 200/300 - Node Loss: 1.1184, Synergy Loss: 0.6441, Total: 2.4067
# Epoch 210/300 - Node Loss: 1.0997, Synergy Loss: 0.6048, Total: 2.3094
# Epoch 220/300 - Node Loss: 1.0850, Synergy Loss: 0.5815, Total: 2.2480
# Epoch 230/300 - Node Loss: 1.0724, Synergy Loss: 0.5634, Total: 2.1992
# Epoch 240/300 - Node Loss: 1.0982, Synergy Loss: 0.5333, Total: 2.1648
# Epoch 250/300 - Node Loss: 1.0753, Synergy Loss: 0.5441, Total: 2.1635
# Epoch 260/300 - Node Loss: 1.0818, Synergy Loss: 0.5076, Total: 2.0971
# Epoch 270/300 - Node Loss: 1.0672, Synergy Loss: 0.5286, Total: 2.1244
# Epoch 280/300 - Node Loss: 1.0662, Synergy Loss: 0.5115, Total: 2.0892
# Epoch 290/300 - Node Loss: 1.0592, Synergy Loss: 0.4920, Total: 2.0433
# Epoch 300/300 - Node Loss: 1.0505, Synergy Loss: 0.5013, Total: 2.0531
# Model saved to: models\gnn_model_ST02-001.pth
# Early stopping at iteration 602, Best Score: 3590.09
# Early stopping at iteration 527, Best Score: 3572.27
# Early stopping at iteration 518, Best Score: 3575.55
# Early stopping at iteration 508, Best Score: 3568.41
# Early stopping at iteration 602, Best Score: 3580.82
# Early stopping at iteration 554, Best Score: 3592.42
# Early stopping at iteration 571, Best Score: 3601.82
# Early stopping at iteration 538, Best Score: 3576.15
# Early stopping at iteration 597, Best Score: 3590.32
# Early stopping at iteration 746, Best Score: 3626.23
# Early stopping at iteration 553, Best Score: 3589.27
# Early stopping at iteration 901, Best Score: 3629.33
# Early stopping at iteration 566, Best Score: 3574.26
# Early stopping at iteration 595, Best Score: 3609.34
# Early stopping at iteration 509, Best Score: 3556.97
# Early stopping at iteration 602, Best Score: 3595.06
# Early stopping at iteration 636, Best Score: 3591.16
# Early stopping at iteration 702, Best Score: 3617.80
# Early stopping at iteration 707, Best Score: 3590.08
# Early stopping at iteration 608, Best Score: 3628.57
# Early stopping at iteration 575, Best Score: 3579.58
# Early stopping at iteration 587, Best Score: 3588.40
# Early stopping at iteration 928, Best Score: 3601.88
# Early stopping at iteration 633, Best Score: 3599.87
# Early stopping at iteration 548, Best Score: 3577.91
# Early stopping at iteration 700, Best Score: 3613.34
# Early stopping at iteration 660, Best Score: 3592.00
# Early stopping at iteration 507, Best Score: 3557.74
# Early stopping at iteration 580, Best Score: 3592.58
# Early stopping at iteration 649, Best Score: 3609.11
# Early stopping at iteration 644, Best Score: 3612.07
# Early stopping at iteration 588, Best Score: 3589.24
# Early stopping at iteration 709, Best Score: 3571.71
# Early stopping at iteration 701, Best Score: 3619.46
# Early stopping at iteration 877, Best Score: 3608.37
# Early stopping at iteration 559, Best Score: 3574.58
# Early stopping at iteration 523, Best Score: 3574.30
# Early stopping at iteration 668, Best Score: 3620.40
# Early stopping at iteration 633, Best Score: 3595.57
# Early stopping at iteration 610, Best Score: 3619.98
# Early stopping at iteration 1070, Best Score: 3622.64
# Early stopping at iteration 545, Best Score: 3585.10
# Early stopping at iteration 686, Best Score: 3588.57
# Early stopping at iteration 532, Best Score: 3560.55
# Early stopping at iteration 580, Best Score: 3572.89
# Early stopping at iteration 609, Best Score: 3600.48
# Early stopping at iteration 595, Best Score: 3603.67
# Early stopping at iteration 671, Best Score: 3630.63
# Early stopping at iteration 620, Best Score: 3589.13
# Early stopping at iteration 713, Best Score: 3595.88
# Early stopping at iteration 612, Best Score: 3590.46
# Early stopping at iteration 562, Best Score: 3584.62
# Early stopping at iteration 618, Best Score: 3603.46
# Early stopping at iteration 558, Best Score: 3596.06
# Early stopping at iteration 524, Best Score: 3560.60
# Early stopping at iteration 691, Best Score: 3604.42
# Early stopping at iteration 571, Best Score: 3571.44
# Early stopping at iteration 512, Best Score: 3565.21
# Early stopping at iteration 613, Best Score: 3630.26
# Early stopping at iteration 851, Best Score: 3606.18
# Early stopping at iteration 653, Best Score: 3605.88
# Early stopping at iteration 685, Best Score: 3622.68
# Early stopping at iteration 500, Best Score: 3554.11
# Early stopping at iteration 514, Best Score: 3566.48
# Early stopping at iteration 546, Best Score: 3588.04
# Early stopping at iteration 716, Best Score: 3606.75
# Early stopping at iteration 501, Best Score: 3556.97
# Early stopping at iteration 580, Best Score: 3585.61
# Early stopping at iteration 532, Best Score: 3588.87
# Early stopping at iteration 881, Best Score: 3623.43
# Early stopping at iteration 622, Best Score: 3604.20
# Early stopping at iteration 554, Best Score: 3575.57
# Early stopping at iteration 531, Best Score: 3584.25
# Early stopping at iteration 567, Best Score: 3571.29
# Early stopping at iteration 612, Best Score: 3587.02
# Early stopping at iteration 501, Best Score: 3556.97
# Early stopping at iteration 601, Best Score: 3584.68
# Early stopping at iteration 572, Best Score: 3595.08
# Early stopping at iteration 732, Best Score: 3624.32
# Early stopping at iteration 546, Best Score: 3572.07
# Early stopping at iteration 506, Best Score: 3556.97
# Early stopping at iteration 589, Best Score: 3594.84
# Early stopping at iteration 674, Best Score: 3618.40
# Early stopping at iteration 551, Best Score: 3596.89
# Early stopping at iteration 628, Best Score: 3619.20
# Early stopping at iteration 626, Best Score: 3588.38
# Early stopping at iteration 569, Best Score: 3605.52
# Early stopping at iteration 624, Best Score: 3595.84
# Early stopping at iteration 510, Best Score: 3563.56
# Early stopping at iteration 594, Best Score: 3575.22
# Early stopping at iteration 521, Best Score: 3583.01
# Early stopping at iteration 604, Best Score: 3603.07
# Early stopping at iteration 652, Best Score: 3586.43
# Early stopping at iteration 660, Best Score: 3604.44
# Early stopping at iteration 533, Best Score: 3585.82
# Early stopping at iteration 659, Best Score: 3611.05
# Early stopping at iteration 664, Best Score: 3615.22
# Early stopping at iteration 701, Best Score: 3605.94
# Early stopping at iteration 526, Best Score: 3576.17
#   Deck Trial 100/250
# Early stopping at iteration 581, Best Score: 3586.42
# Early stopping at iteration 557, Best Score: 3589.68
# Early stopping at iteration 516, Best Score: 3569.36
# Early stopping at iteration 561, Best Score: 3584.61
# Early stopping at iteration 508, Best Score: 3563.21
# Early stopping at iteration 593, Best Score: 3604.73
# Early stopping at iteration 659, Best Score: 3615.27
# Early stopping at iteration 570, Best Score: 3592.49
# Early stopping at iteration 520, Best Score: 3566.46
# Early stopping at iteration 501, Best Score: 3557.47
# Early stopping at iteration 500, Best Score: 3554.11
# Early stopping at iteration 807, Best Score: 3629.95
# Early stopping at iteration 616, Best Score: 3604.57
# Early stopping at iteration 535, Best Score: 3595.97
# Early stopping at iteration 737, Best Score: 3619.43
# Early stopping at iteration 548, Best Score: 3574.25
# Early stopping at iteration 721, Best Score: 3624.06
# Early stopping at iteration 1063, Best Score: 3622.29
# Early stopping at iteration 701, Best Score: 3621.21
# Early stopping at iteration 618, Best Score: 3618.37
# Early stopping at iteration 604, Best Score: 3611.61
# Early stopping at iteration 527, Best Score: 3570.74
# Early stopping at iteration 622, Best Score: 3608.24
# Early stopping at iteration 540, Best Score: 3569.14
# Early stopping at iteration 571, Best Score: 3594.81
# Early stopping at iteration 638, Best Score: 3601.56
# Early stopping at iteration 550, Best Score: 3594.11
# Early stopping at iteration 558, Best Score: 3595.35
# Early stopping at iteration 531, Best Score: 3580.62
# Early stopping at iteration 529, Best Score: 3578.85
# Early stopping at iteration 546, Best Score: 3588.84
# Early stopping at iteration 652, Best Score: 3595.18
# Early stopping at iteration 545, Best Score: 3585.21
# Early stopping at iteration 542, Best Score: 3573.98
# Early stopping at iteration 1008, Best Score: 3633.53
# Early stopping at iteration 519, Best Score: 3572.64
# Early stopping at iteration 715, Best Score: 3605.61
# Early stopping at iteration 527, Best Score: 3575.65
# Early stopping at iteration 719, Best Score: 3604.75
# Early stopping at iteration 624, Best Score: 3603.29
# Early stopping at iteration 534, Best Score: 3582.11
# Early stopping at iteration 704, Best Score: 3607.55
# Early stopping at iteration 555, Best Score: 3604.26
# Early stopping at iteration 541, Best Score: 3582.30
# Early stopping at iteration 787, Best Score: 3621.59
# Early stopping at iteration 808, Best Score: 3622.90
# Early stopping at iteration 500, Best Score: 3554.11
# Early stopping at iteration 572, Best Score: 3575.76
# Early stopping at iteration 621, Best Score: 3594.97
# Early stopping at iteration 579, Best Score: 3582.30
# Early stopping at iteration 552, Best Score: 3596.19
# Early stopping at iteration 532, Best Score: 3573.84
# Early stopping at iteration 519, Best Score: 3582.42
# Early stopping at iteration 851, Best Score: 3623.55
# Early stopping at iteration 549, Best Score: 3573.54
# Early stopping at iteration 612, Best Score: 3615.81
# Early stopping at iteration 648, Best Score: 3620.42
# Early stopping at iteration 559, Best Score: 3574.45
# Early stopping at iteration 692, Best Score: 3597.30
# Early stopping at iteration 665, Best Score: 3617.47
# Early stopping at iteration 539, Best Score: 3572.96
# Early stopping at iteration 595, Best Score: 3576.36
# Early stopping at iteration 549, Best Score: 3576.33
# Early stopping at iteration 654, Best Score: 3595.70
# Early stopping at iteration 693, Best Score: 3591.94
# Early stopping at iteration 541, Best Score: 3598.80
# Early stopping at iteration 590, Best Score: 3589.95
# Early stopping at iteration 524, Best Score: 3568.99
# Early stopping at iteration 538, Best Score: 3587.37
# Early stopping at iteration 767, Best Score: 3599.87
# Early stopping at iteration 625, Best Score: 3571.44
# Early stopping at iteration 510, Best Score: 3571.29
# Early stopping at iteration 650, Best Score: 3598.14
# Early stopping at iteration 537, Best Score: 3565.22
# Early stopping at iteration 619, Best Score: 3572.43
# Early stopping at iteration 612, Best Score: 3601.66
# Early stopping at iteration 639, Best Score: 3589.84
# Early stopping at iteration 534, Best Score: 3590.00
# Early stopping at iteration 566, Best Score: 3598.53
# Early stopping at iteration 842, Best Score: 3634.08
# Early stopping at iteration 699, Best Score: 3594.85
# Early stopping at iteration 691, Best Score: 3633.53
# Early stopping at iteration 569, Best Score: 3599.40
# Early stopping at iteration 631, Best Score: 3590.80
# Early stopping at iteration 536, Best Score: 3584.74
# Early stopping at iteration 635, Best Score: 3614.18
# Early stopping at iteration 614, Best Score: 3600.96
# Early stopping at iteration 634, Best Score: 3624.39
# Early stopping at iteration 665, Best Score: 3604.64
# Early stopping at iteration 734, Best Score: 3625.81
# Early stopping at iteration 637, Best Score: 3608.57
# Early stopping at iteration 568, Best Score: 3581.59
# Early stopping at iteration 535, Best Score: 3590.74
# Early stopping at iteration 643, Best Score: 3607.00
# Early stopping at iteration 559, Best Score: 3597.33
# Early stopping at iteration 626, Best Score: 3584.78
# Early stopping at iteration 566, Best Score: 3586.77
# Early stopping at iteration 608, Best Score: 3623.92
# Early stopping at iteration 572, Best Score: 3581.93
# Early stopping at iteration 699, Best Score: 3588.06
#   Deck Trial 200/250
# Early stopping at iteration 573, Best Score: 3593.98
# Early stopping at iteration 547, Best Score: 3586.50
# Early stopping at iteration 562, Best Score: 3583.99
# Early stopping at iteration 630, Best Score: 3585.62
# Early stopping at iteration 618, Best Score: 3585.98
# Early stopping at iteration 606, Best Score: 3595.99
# Early stopping at iteration 882, Best Score: 3631.25
# Early stopping at iteration 720, Best Score: 3589.51
# Early stopping at iteration 601, Best Score: 3589.79
# Early stopping at iteration 569, Best Score: 3603.28
# Early stopping at iteration 664, Best Score: 3599.48
# Early stopping at iteration 623, Best Score: 3615.06
# Early stopping at iteration 788, Best Score: 3606.51
# Early stopping at iteration 620, Best Score: 3603.15
# Early stopping at iteration 587, Best Score: 3609.75
# Early stopping at iteration 509, Best Score: 3563.34
# Early stopping at iteration 816, Best Score: 3613.29
# Early stopping at iteration 592, Best Score: 3607.66
# Early stopping at iteration 556, Best Score: 3582.51
# Early stopping at iteration 753, Best Score: 3625.69
# Early stopping at iteration 684, Best Score: 3596.50
# Early stopping at iteration 550, Best Score: 3592.41
# Early stopping at iteration 704, Best Score: 3601.70
# Early stopping at iteration 629, Best Score: 3602.55
# Early stopping at iteration 572, Best Score: 3601.30
# Early stopping at iteration 689, Best Score: 3618.66
# Early stopping at iteration 555, Best Score: 3584.78
# Early stopping at iteration 614, Best Score: 3608.23
# Early stopping at iteration 566, Best Score: 3592.97
# Early stopping at iteration 574, Best Score: 3594.31
# Early stopping at iteration 766, Best Score: 3607.66
# Early stopping at iteration 681, Best Score: 3609.62
# Early stopping at iteration 901, Best Score: 3616.61
# Early stopping at iteration 562, Best Score: 3591.51
# Early stopping at iteration 513, Best Score: 3560.18
# Early stopping at iteration 556, Best Score: 3578.62
# Early stopping at iteration 690, Best Score: 3628.26
# Early stopping at iteration 574, Best Score: 3585.93
# Early stopping at iteration 557, Best Score: 3581.32
# Early stopping at iteration 619, Best Score: 3600.42
# Early stopping at iteration 540, Best Score: 3578.72
# Early stopping at iteration 566, Best Score: 3574.74
# Early stopping at iteration 563, Best Score: 3584.68
# Early stopping at iteration 612, Best Score: 3600.33
# Early stopping at iteration 567, Best Score: 3593.26
# Early stopping at iteration 599, Best Score: 3594.80
# Early stopping at iteration 719, Best Score: 3611.38
# Early stopping at iteration 529, Best Score: 3584.26
# Early stopping at iteration 524, Best Score: 3571.31
# Early stopping at iteration 685, Best Score: 3616.75
# Early stopping at iteration 755, Best Score: 3623.14
# GNN Trial 1 completed with 250 decks.
#
# GNN Trial 2/20
# Training GNN and building synergy matrix...
# Epoch 10/300 - Node Loss: 56.6675, Synergy Loss: 2.4994, Total: 61.6662
# Epoch 20/300 - Node Loss: 6.7443, Synergy Loss: 2.3888, Total: 11.5219
# Epoch 30/300 - Node Loss: 2.5476, Synergy Loss: 2.3405, Total: 7.2286
# Epoch 40/300 - Node Loss: 1.5161, Synergy Loss: 2.2349, Total: 5.9860
# Epoch 50/300 - Node Loss: 1.0744, Synergy Loss: 2.1009, Total: 5.2762
# Epoch 60/300 - Node Loss: 1.0424, Synergy Loss: 1.9788, Total: 5.0001
# Epoch 70/300 - Node Loss: 1.0130, Synergy Loss: 1.8754, Total: 4.7638
# Epoch 80/300 - Node Loss: 1.0166, Synergy Loss: 1.8042, Total: 4.6251
# Epoch 90/300 - Node Loss: 1.0249, Synergy Loss: 1.7365, Total: 4.4979
# Epoch 100/300 - Node Loss: 1.0608, Synergy Loss: 1.6083, Total: 4.2774
# Epoch 110/300 - Node Loss: 1.1467, Synergy Loss: 1.4351, Total: 4.0170
# Epoch 120/300 - Node Loss: 1.0651, Synergy Loss: 1.4693, Total: 4.0036
# Epoch 130/300 - Node Loss: 1.0984, Synergy Loss: 1.2853, Total: 3.6689
# Epoch 140/300 - Node Loss: 1.2088, Synergy Loss: 1.0588, Total: 3.3264
# Epoch 150/300 - Node Loss: 1.2527, Synergy Loss: 0.9894, Total: 3.2316
# Epoch 160/300 - Node Loss: 1.3455, Synergy Loss: 0.9105, Total: 3.1664
# Epoch 170/300 - Node Loss: 1.2433, Synergy Loss: 0.8900, Total: 3.0233
# Epoch 180/300 - Node Loss: 1.2484, Synergy Loss: 0.8666, Total: 2.9815
# Epoch 190/300 - Node Loss: 1.2314, Synergy Loss: 0.8815, Total: 2.9944
# Epoch 200/300 - Node Loss: 1.1802, Synergy Loss: 0.8473, Total: 2.8747
# Epoch 210/300 - Node Loss: 1.1950, Synergy Loss: 0.8140, Total: 2.8230
# Epoch 220/300 - Node Loss: 1.2288, Synergy Loss: 0.8060, Total: 2.8408
# Epoch 230/300 - Node Loss: 1.1852, Synergy Loss: 0.7660, Total: 2.7173
# Epoch 240/300 - Node Loss: 1.1348, Synergy Loss: 0.7369, Total: 2.6085
# Epoch 250/300 - Node Loss: 1.0969, Synergy Loss: 0.7276, Total: 2.5522
# Epoch 260/300 - Node Loss: 1.1258, Synergy Loss: 0.6996, Total: 2.5250
# Epoch 270/300 - Node Loss: 1.1332, Synergy Loss: 0.6470, Total: 2.4272
# Epoch 280/300 - Node Loss: 1.1930, Synergy Loss: 0.6177, Total: 2.4283
# Epoch 290/300 - Node Loss: 1.1539, Synergy Loss: 0.6255, Total: 2.4050
# Epoch 300/300 - Node Loss: 1.1464, Synergy Loss: 0.6381, Total: 2.4226
# Existing model archived to: 20250310_103954_gnn_model_ST02-001.pth
# Model saved to: models\gnn_model_ST02-001.pth
# Early stopping at iteration 625, Best Score: 3347.93
# Early stopping at iteration 608, Best Score: 3344.24
# Early stopping at iteration 606, Best Score: 3321.28
# Early stopping at iteration 532, Best Score: 3317.67
# Early stopping at iteration 505, Best Score: 3301.42
# Early stopping at iteration 681, Best Score: 3337.44
# Early stopping at iteration 504, Best Score: 3301.35
# Early stopping at iteration 524, Best Score: 3311.64
# Early stopping at iteration 563, Best Score: 3330.11
# Early stopping at iteration 654, Best Score: 3341.04
# Early stopping at iteration 516, Best Score: 3304.59
# Early stopping at iteration 563, Best Score: 3310.95
# Early stopping at iteration 532, Best Score: 3311.57
# Early stopping at iteration 631, Best Score: 3332.77
# Early stopping at iteration 770, Best Score: 3374.19
# Early stopping at iteration 711, Best Score: 3333.07
# Early stopping at iteration 779, Best Score: 3370.11
# Early stopping at iteration 512, Best Score: 3301.43
# Early stopping at iteration 617, Best Score: 3327.36
# Early stopping at iteration 626, Best Score: 3336.41
# Early stopping at iteration 556, Best Score: 3343.27
# Early stopping at iteration 663, Best Score: 3350.04
# Early stopping at iteration 511, Best Score: 3311.01
# Early stopping at iteration 595, Best Score: 3319.10
# Early stopping at iteration 601, Best Score: 3331.45
# Early stopping at iteration 600, Best Score: 3350.58
# Early stopping at iteration 533, Best Score: 3301.34
# Early stopping at iteration 631, Best Score: 3344.94
# Early stopping at iteration 588, Best Score: 3323.30
# Early stopping at iteration 537, Best Score: 3311.61
# Early stopping at iteration 595, Best Score: 3341.81
# Early stopping at iteration 668, Best Score: 3373.56
# Early stopping at iteration 636, Best Score: 3325.49
# Early stopping at iteration 594, Best Score: 3328.30
# Early stopping at iteration 552, Best Score: 3328.58
# Early stopping at iteration 672, Best Score: 3364.81
# Early stopping at iteration 588, Best Score: 3333.77
# Early stopping at iteration 742, Best Score: 3346.14
# Early stopping at iteration 524, Best Score: 3311.63
# Early stopping at iteration 547, Best Score: 3328.13
# Early stopping at iteration 950, Best Score: 3381.14
# Early stopping at iteration 599, Best Score: 3322.85
# Early stopping at iteration 603, Best Score: 3352.52
# Early stopping at iteration 571, Best Score: 3308.76
# Early stopping at iteration 643, Best Score: 3365.32
# Early stopping at iteration 643, Best Score: 3353.27
# Early stopping at iteration 702, Best Score: 3358.69
# Early stopping at iteration 500, Best Score: 3298.55
# Early stopping at iteration 551, Best Score: 3311.44
# Early stopping at iteration 581, Best Score: 3324.76
# Early stopping at iteration 571, Best Score: 3314.91
# Early stopping at iteration 520, Best Score: 3308.82
# Early stopping at iteration 782, Best Score: 3359.25
# Early stopping at iteration 522, Best Score: 3314.57
# Early stopping at iteration 528, Best Score: 3311.68
# Early stopping at iteration 558, Best Score: 3317.69
# Early stopping at iteration 724, Best Score: 3350.65
# Early stopping at iteration 567, Best Score: 3329.73
# Early stopping at iteration 509, Best Score: 3301.31
# Early stopping at iteration 697, Best Score: 3344.96
# Early stopping at iteration 653, Best Score: 3359.58
# Early stopping at iteration 719, Best Score: 3348.72
# Early stopping at iteration 738, Best Score: 3387.53
# Early stopping at iteration 736, Best Score: 3366.47
# Early stopping at iteration 594, Best Score: 3346.85
# Early stopping at iteration 538, Best Score: 3323.14
# Early stopping at iteration 635, Best Score: 3344.61
# Early stopping at iteration 505, Best Score: 3301.42
# Early stopping at iteration 559, Best Score: 3336.75
# Early stopping at iteration 775, Best Score: 3360.45
# Early stopping at iteration 593, Best Score: 3309.00
# Early stopping at iteration 624, Best Score: 3355.53
# Early stopping at iteration 502, Best Score: 3301.24
# Early stopping at iteration 524, Best Score: 3311.67
# Early stopping at iteration 781, Best Score: 3354.60
# Early stopping at iteration 560, Best Score: 3311.62
# Early stopping at iteration 695, Best Score: 3366.18
# Early stopping at iteration 532, Best Score: 3315.00
# Early stopping at iteration 588, Best Score: 3321.42
# Early stopping at iteration 608, Best Score: 3338.34
# Early stopping at iteration 502, Best Score: 3301.24
# Early stopping at iteration 637, Best Score: 3351.38
# Early stopping at iteration 507, Best Score: 3301.43
# Early stopping at iteration 564, Best Score: 3348.46
# Early stopping at iteration 506, Best Score: 3301.42
# Early stopping at iteration 628, Best Score: 3320.64
# Early stopping at iteration 700, Best Score: 3336.03
# Early stopping at iteration 581, Best Score: 3334.13
# Early stopping at iteration 535, Best Score: 3311.58
# Early stopping at iteration 527, Best Score: 3301.43
# Early stopping at iteration 522, Best Score: 3317.28
# Early stopping at iteration 668, Best Score: 3371.48
# Early stopping at iteration 785, Best Score: 3324.95
# Early stopping at iteration 509, Best Score: 3307.43
# Early stopping at iteration 519, Best Score: 3317.60
# Early stopping at iteration 549, Best Score: 3327.40
# Early stopping at iteration 619, Best Score: 3350.73
# Early stopping at iteration 572, Best Score: 3320.89
# Early stopping at iteration 868, Best Score: 3342.68
#   Deck Trial 100/250
# Early stopping at iteration 516, Best Score: 3301.43
# Early stopping at iteration 545, Best Score: 3324.11
# Early stopping at iteration 778, Best Score: 3359.15
# Early stopping at iteration 563, Best Score: 3342.21
# Early stopping at iteration 755, Best Score: 3362.58
# Early stopping at iteration 718, Best Score: 3341.46
# Early stopping at iteration 610, Best Score: 3324.67
# Early stopping at iteration 785, Best Score: 3354.71
# Early stopping at iteration 614, Best Score: 3331.80
# Early stopping at iteration 500, Best Score: 3298.55
# Early stopping at iteration 512, Best Score: 3310.82
# Early stopping at iteration 568, Best Score: 3340.86
# Early stopping at iteration 504, Best Score: 3301.35
# Early stopping at iteration 781, Best Score: 3363.76
# Early stopping at iteration 937, Best Score: 3356.33
# Early stopping at iteration 621, Best Score: 3337.51
# Early stopping at iteration 738, Best Score: 3351.82
# Early stopping at iteration 578, Best Score: 3345.33
# Early stopping at iteration 736, Best Score: 3351.23
# Early stopping at iteration 608, Best Score: 3317.81
# Early stopping at iteration 578, Best Score: 3341.54
# Early stopping at iteration 503, Best Score: 3301.24
# Early stopping at iteration 676, Best Score: 3342.86
# Early stopping at iteration 577, Best Score: 3344.93
# Early stopping at iteration 522, Best Score: 3311.67
# Early stopping at iteration 517, Best Score: 3301.88
# Early stopping at iteration 946, Best Score: 3366.08
# Early stopping at iteration 510, Best Score: 3301.34
# Early stopping at iteration 792, Best Score: 3363.17
# Early stopping at iteration 595, Best Score: 3334.66
# Early stopping at iteration 590, Best Score: 3337.52
# Early stopping at iteration 503, Best Score: 3301.24
# Early stopping at iteration 584, Best Score: 3317.67
# Early stopping at iteration 632, Best Score: 3354.65
# Early stopping at iteration 534, Best Score: 3307.58
# Early stopping at iteration 583, Best Score: 3330.16
# Early stopping at iteration 630, Best Score: 3341.62
# Early stopping at iteration 597, Best Score: 3336.52
# Early stopping at iteration 623, Best Score: 3342.30
# Early stopping at iteration 636, Best Score: 3311.68
# Early stopping at iteration 565, Best Score: 3311.76
# Early stopping at iteration 655, Best Score: 3374.86
# Early stopping at iteration 571, Best Score: 3311.65
# Early stopping at iteration 579, Best Score: 3331.34
# Early stopping at iteration 728, Best Score: 3340.12
# Early stopping at iteration 881, Best Score: 3377.69
# Early stopping at iteration 508, Best Score: 3301.35
# Early stopping at iteration 562, Best Score: 3343.03
# Early stopping at iteration 542, Best Score: 3348.31
# Early stopping at iteration 548, Best Score: 3320.99
# Early stopping at iteration 771, Best Score: 3369.27
# Early stopping at iteration 546, Best Score: 3321.69
# Early stopping at iteration 579, Best Score: 3318.23
# Early stopping at iteration 565, Best Score: 3313.52
# Early stopping at iteration 567, Best Score: 3322.19
# Early stopping at iteration 596, Best Score: 3331.48
# Early stopping at iteration 621, Best Score: 3336.48
# Early stopping at iteration 577, Best Score: 3338.16
# Early stopping at iteration 570, Best Score: 3338.25
# Early stopping at iteration 728, Best Score: 3354.71
# Early stopping at iteration 541, Best Score: 3324.47
# Early stopping at iteration 588, Best Score: 3332.14
# Early stopping at iteration 588, Best Score: 3330.49
# Early stopping at iteration 541, Best Score: 3306.20
# Early stopping at iteration 628, Best Score: 3325.51
# Early stopping at iteration 632, Best Score: 3353.10
# Early stopping at iteration 529, Best Score: 3317.40
# Early stopping at iteration 547, Best Score: 3307.52
# Early stopping at iteration 652, Best Score: 3323.80
# Early stopping at iteration 630, Best Score: 3325.82
# Early stopping at iteration 591, Best Score: 3327.71
# Early stopping at iteration 572, Best Score: 3329.19
# Early stopping at iteration 514, Best Score: 3301.33
# Early stopping at iteration 660, Best Score: 3326.72
# Early stopping at iteration 636, Best Score: 3339.52
# Early stopping at iteration 549, Best Score: 3310.90
# Early stopping at iteration 511, Best Score: 3301.33
# Early stopping at iteration 583, Best Score: 3321.37
# Early stopping at iteration 501, Best Score: 3301.24
# Early stopping at iteration 716, Best Score: 3369.59
# Early stopping at iteration 644, Best Score: 3328.67
# Early stopping at iteration 561, Best Score: 3335.10
# Early stopping at iteration 501, Best Score: 3301.34
# Early stopping at iteration 712, Best Score: 3359.41
# Early stopping at iteration 711, Best Score: 3338.79
# Early stopping at iteration 620, Best Score: 3329.30
# Early stopping at iteration 614, Best Score: 3333.23
# Early stopping at iteration 560, Best Score: 3329.21
# Early stopping at iteration 607, Best Score: 3333.96
# Early stopping at iteration 796, Best Score: 3355.63
# Early stopping at iteration 618, Best Score: 3335.14
# Early stopping at iteration 533, Best Score: 3307.53
# Early stopping at iteration 696, Best Score: 3356.02
# Early stopping at iteration 526, Best Score: 3317.31
# Early stopping at iteration 518, Best Score: 3317.10
# Early stopping at iteration 548, Best Score: 3321.86
# Early stopping at iteration 608, Best Score: 3330.74
# Early stopping at iteration 548, Best Score: 3332.76
# Early stopping at iteration 523, Best Score: 3311.68
# Early stopping at iteration 547, Best Score: 3322.81
#   Deck Trial 200/250
# Early stopping at iteration 660, Best Score: 3351.28
# Early stopping at iteration 770, Best Score: 3351.62
# Early stopping at iteration 543, Best Score: 3319.09
# Early stopping at iteration 622, Best Score: 3354.23
# Early stopping at iteration 584, Best Score: 3351.55
# Early stopping at iteration 649, Best Score: 3355.74
# Early stopping at iteration 500, Best Score: 3298.55
# Early stopping at iteration 691, Best Score: 3341.97
# Early stopping at iteration 772, Best Score: 3338.71
# Early stopping at iteration 647, Best Score: 3351.05
# Early stopping at iteration 550, Best Score: 3318.86
# Early stopping at iteration 634, Best Score: 3355.12
# Early stopping at iteration 508, Best Score: 3301.42
# Early stopping at iteration 587, Best Score: 3334.28
# Early stopping at iteration 653, Best Score: 3348.33
# Early stopping at iteration 877, Best Score: 3345.93
# Early stopping at iteration 587, Best Score: 3330.65
# Early stopping at iteration 995, Best Score: 3335.24
# Early stopping at iteration 555, Best Score: 3312.53
# Early stopping at iteration 655, Best Score: 3325.16
# Early stopping at iteration 683, Best Score: 3351.16
# Early stopping at iteration 743, Best Score: 3352.30
# Early stopping at iteration 671, Best Score: 3358.56
# Early stopping at iteration 592, Best Score: 3343.17
# Early stopping at iteration 572, Best Score: 3305.35
# Early stopping at iteration 628, Best Score: 3323.08
# Early stopping at iteration 681, Best Score: 3365.69
# Early stopping at iteration 553, Best Score: 3315.25
# Early stopping at iteration 779, Best Score: 3353.81
# Early stopping at iteration 589, Best Score: 3338.17
# Early stopping at iteration 642, Best Score: 3345.81
# Early stopping at iteration 526, Best Score: 3301.35
# Early stopping at iteration 570, Best Score: 3347.67
# Early stopping at iteration 574, Best Score: 3330.45
# Early stopping at iteration 531, Best Score: 3311.69
# Early stopping at iteration 527, Best Score: 3306.90
# Early stopping at iteration 625, Best Score: 3343.97
# Early stopping at iteration 563, Best Score: 3317.69
# Early stopping at iteration 621, Best Score: 3321.96
# Early stopping at iteration 643, Best Score: 3339.78
# Early stopping at iteration 582, Best Score: 3343.55
# Early stopping at iteration 823, Best Score: 3364.50
# Early stopping at iteration 586, Best Score: 3345.39
# Early stopping at iteration 511, Best Score: 3301.95
# Early stopping at iteration 595, Best Score: 3327.87
# Early stopping at iteration 510, Best Score: 3301.43
# Early stopping at iteration 500, Best Score: 3298.55
# Early stopping at iteration 512, Best Score: 3301.42
# Early stopping at iteration 735, Best Score: 3353.78
# Early stopping at iteration 590, Best Score: 3335.35
# Early stopping at iteration 510, Best Score: 3310.99
# GNN Trial 2 completed with 250 decks.
#
# GNN Trial 3/20
# Training GNN and building synergy matrix...
# Epoch 10/300 - Node Loss: 58.3723, Synergy Loss: 2.8208, Total: 64.0139
# Epoch 20/300 - Node Loss: 6.1805, Synergy Loss: 2.6216, Total: 11.4237
# Epoch 30/300 - Node Loss: 2.9277, Synergy Loss: 2.4936, Total: 7.9149
# Epoch 40/300 - Node Loss: 1.2814, Synergy Loss: 2.3775, Total: 6.0364
# Epoch 50/300 - Node Loss: 1.1145, Synergy Loss: 2.2533, Total: 5.6210
# Epoch 60/300 - Node Loss: 1.0117, Synergy Loss: 2.1225, Total: 5.2566
# Epoch 70/300 - Node Loss: 1.0084, Synergy Loss: 1.9822, Total: 4.9728
# Epoch 80/300 - Node Loss: 1.0133, Synergy Loss: 1.8258, Total: 4.6648
# Epoch 90/300 - Node Loss: 1.0636, Synergy Loss: 1.6433, Total: 4.3502
# Epoch 100/300 - Node Loss: 1.0760, Synergy Loss: 1.4714, Total: 4.0188
# Epoch 110/300 - Node Loss: 1.0730, Synergy Loss: 1.3694, Total: 3.8117
# Epoch 120/300 - Node Loss: 1.2155, Synergy Loss: 1.1433, Total: 3.5022
# Epoch 130/300 - Node Loss: 1.3313, Synergy Loss: 0.9734, Total: 3.2782
# Epoch 140/300 - Node Loss: 1.2989, Synergy Loss: 0.9143, Total: 3.1275
# Epoch 150/300 - Node Loss: 1.4424, Synergy Loss: 0.8632, Total: 3.1688
# Epoch 160/300 - Node Loss: 1.2201, Synergy Loss: 0.8676, Total: 2.9554
# Epoch 170/300 - Node Loss: 1.2165, Synergy Loss: 0.9461, Total: 3.1087
# Early stopping at epoch 179
# Existing model archived to: 20250310_104430_gnn_model_ST02-001.pth
# Model saved to: models\gnn_model_ST02-001.pth
# Early stopping at iteration 577, Best Score: 2448.03
# Early stopping at iteration 615, Best Score: 2442.36
# Early stopping at iteration 568, Best Score: 2452.60
# Early stopping at iteration 843, Best Score: 2459.22
# Early stopping at iteration 593, Best Score: 2458.21
# Early stopping at iteration 629, Best Score: 2464.66
# Early stopping at iteration 715, Best Score: 2470.24
# Early stopping at iteration 572, Best Score: 2452.42
# Early stopping at iteration 594, Best Score: 2474.36
# Early stopping at iteration 858, Best Score: 2458.04
# Early stopping at iteration 566, Best Score: 2446.19
# Early stopping at iteration 855, Best Score: 2466.17
# Early stopping at iteration 951, Best Score: 2454.18
# Early stopping at iteration 605, Best Score: 2459.14
# Early stopping at iteration 664, Best Score: 2479.99
# Early stopping at iteration 819, Best Score: 2481.05
# Early stopping at iteration 592, Best Score: 2477.10
# Early stopping at iteration 871, Best Score: 2464.63
# Early stopping at iteration 748, Best Score: 2465.38
# Early stopping at iteration 583, Best Score: 2456.29
# Early stopping at iteration 635, Best Score: 2458.26
# Early stopping at iteration 720, Best Score: 2466.91
# Early stopping at iteration 543, Best Score: 2439.67
# Early stopping at iteration 801, Best Score: 2475.25
# Early stopping at iteration 612, Best Score: 2458.79
# Early stopping at iteration 596, Best Score: 2475.56
# Early stopping at iteration 584, Best Score: 2461.74
# Early stopping at iteration 619, Best Score: 2445.28
# Early stopping at iteration 560, Best Score: 2450.24
# Early stopping at iteration 638, Best Score: 2447.71
# Early stopping at iteration 561, Best Score: 2451.80
# Early stopping at iteration 741, Best Score: 2463.95
# Early stopping at iteration 1076, Best Score: 2468.83
# Early stopping at iteration 613, Best Score: 2456.74
# Early stopping at iteration 770, Best Score: 2449.93
# Early stopping at iteration 564, Best Score: 2451.49
# Early stopping at iteration 782, Best Score: 2439.62
# Early stopping at iteration 522, Best Score: 2443.07
# Early stopping at iteration 706, Best Score: 2454.36
# Early stopping at iteration 567, Best Score: 2455.73
# Early stopping at iteration 631, Best Score: 2459.91
# Early stopping at iteration 571, Best Score: 2457.78
# Early stopping at iteration 674, Best Score: 2459.39
# Early stopping at iteration 684, Best Score: 2482.36
# Early stopping at iteration 529, Best Score: 2437.53
# Early stopping at iteration 896, Best Score: 2455.91
# Early stopping at iteration 599, Best Score: 2444.78
# Early stopping at iteration 601, Best Score: 2448.81
# Early stopping at iteration 732, Best Score: 2461.51
# Early stopping at iteration 544, Best Score: 2439.28
# Early stopping at iteration 790, Best Score: 2457.77
# Early stopping at iteration 683, Best Score: 2478.92
# Early stopping at iteration 579, Best Score: 2457.11
# Early stopping at iteration 666, Best Score: 2456.19
# Early stopping at iteration 1058, Best Score: 2463.67
# Early stopping at iteration 586, Best Score: 2435.75
# Early stopping at iteration 614, Best Score: 2463.77
# Early stopping at iteration 654, Best Score: 2465.02
# Early stopping at iteration 724, Best Score: 2463.55
# Early stopping at iteration 764, Best Score: 2450.01
# Early stopping at iteration 824, Best Score: 2449.80
# Early stopping at iteration 719, Best Score: 2458.24
# Early stopping at iteration 605, Best Score: 2468.34
# Early stopping at iteration 619, Best Score: 2463.46
# Early stopping at iteration 759, Best Score: 2473.37
# Early stopping at iteration 664, Best Score: 2466.75
# Early stopping at iteration 783, Best Score: 2469.54
# Early stopping at iteration 645, Best Score: 2450.02
# Early stopping at iteration 553, Best Score: 2442.05
# Early stopping at iteration 717, Best Score: 2475.19
# Early stopping at iteration 565, Best Score: 2453.40
# Early stopping at iteration 808, Best Score: 2481.04
# Early stopping at iteration 739, Best Score: 2456.03
# Early stopping at iteration 545, Best Score: 2449.90
# Early stopping at iteration 655, Best Score: 2469.40
# Early stopping at iteration 605, Best Score: 2457.14
# Early stopping at iteration 575, Best Score: 2458.55
# Early stopping at iteration 578, Best Score: 2463.66
# Early stopping at iteration 645, Best Score: 2467.22
# Early stopping at iteration 641, Best Score: 2466.01
# Early stopping at iteration 674, Best Score: 2476.63
# Early stopping at iteration 1038, Best Score: 2471.61
# Early stopping at iteration 623, Best Score: 2458.01
# Early stopping at iteration 575, Best Score: 2451.23
# Early stopping at iteration 662, Best Score: 2460.26
# Early stopping at iteration 566, Best Score: 2459.89
# Early stopping at iteration 560, Best Score: 2454.90
# Early stopping at iteration 519, Best Score: 2434.77
# Early stopping at iteration 598, Best Score: 2467.60
# Early stopping at iteration 553, Best Score: 2452.26
# Early stopping at iteration 591, Best Score: 2456.77
# Early stopping at iteration 704, Best Score: 2470.99
# Early stopping at iteration 557, Best Score: 2460.32
# Early stopping at iteration 599, Best Score: 2467.90
# Early stopping at iteration 892, Best Score: 2470.44
# Early stopping at iteration 610, Best Score: 2469.69
# Early stopping at iteration 606, Best Score: 2466.42
# Early stopping at iteration 622, Best Score: 2445.42
# Early stopping at iteration 590, Best Score: 2459.88
#   Deck Trial 100/250
# Early stopping at iteration 555, Best Score: 2450.26
# Early stopping at iteration 1129, Best Score: 2463.88
# Early stopping at iteration 587, Best Score: 2466.88
# Early stopping at iteration 658, Best Score: 2476.97
# Early stopping at iteration 650, Best Score: 2470.52
# Early stopping at iteration 599, Best Score: 2460.09
# Early stopping at iteration 665, Best Score: 2466.28
# Early stopping at iteration 648, Best Score: 2452.50
# Early stopping at iteration 653, Best Score: 2458.59
# Early stopping at iteration 555, Best Score: 2442.78
# Early stopping at iteration 672, Best Score: 2458.22
# Early stopping at iteration 635, Best Score: 2452.84
# Early stopping at iteration 780, Best Score: 2470.30
# Early stopping at iteration 614, Best Score: 2453.06
# Early stopping at iteration 672, Best Score: 2462.04
# Early stopping at iteration 564, Best Score: 2446.97
# Early stopping at iteration 585, Best Score: 2449.67
# Early stopping at iteration 624, Best Score: 2464.02
# Early stopping at iteration 955, Best Score: 2468.19
# Early stopping at iteration 661, Best Score: 2461.29
# Early stopping at iteration 1198, Best Score: 2474.24
# Early stopping at iteration 943, Best Score: 2449.55
# Early stopping at iteration 670, Best Score: 2459.08
# Early stopping at iteration 994, Best Score: 2471.21
# Early stopping at iteration 616, Best Score: 2466.06
# Early stopping at iteration 753, Best Score: 2477.67
# Early stopping at iteration 601, Best Score: 2459.70
# Early stopping at iteration 931, Best Score: 2471.55
# Early stopping at iteration 535, Best Score: 2444.01
# Early stopping at iteration 582, Best Score: 2448.22
# Early stopping at iteration 547, Best Score: 2456.64
# Early stopping at iteration 569, Best Score: 2449.39
# Early stopping at iteration 620, Best Score: 2462.86
# Early stopping at iteration 636, Best Score: 2460.02
# Early stopping at iteration 605, Best Score: 2464.49
# Early stopping at iteration 587, Best Score: 2444.86
# Early stopping at iteration 752, Best Score: 2463.20
# Early stopping at iteration 742, Best Score: 2465.80
# Early stopping at iteration 720, Best Score: 2461.09
# Early stopping at iteration 700, Best Score: 2463.12
# Early stopping at iteration 726, Best Score: 2447.52
# Early stopping at iteration 627, Best Score: 2469.95
# Early stopping at iteration 567, Best Score: 2445.91
# Early stopping at iteration 588, Best Score: 2458.41
# Early stopping at iteration 558, Best Score: 2448.35
# Early stopping at iteration 552, Best Score: 2453.36
# Early stopping at iteration 617, Best Score: 2456.93
# Early stopping at iteration 542, Best Score: 2449.26
# Early stopping at iteration 592, Best Score: 2459.26
# Early stopping at iteration 637, Best Score: 2443.05
# Early stopping at iteration 548, Best Score: 2455.68
# Early stopping at iteration 538, Best Score: 2442.28
# Early stopping at iteration 823, Best Score: 2460.46
# Early stopping at iteration 836, Best Score: 2451.14
# Early stopping at iteration 542, Best Score: 2449.11
# Early stopping at iteration 692, Best Score: 2471.44
# Early stopping at iteration 659, Best Score: 2453.88
# Early stopping at iteration 661, Best Score: 2461.41
# Early stopping at iteration 530, Best Score: 2448.97
# Early stopping at iteration 616, Best Score: 2447.06
# Early stopping at iteration 619, Best Score: 2436.62
# Early stopping at iteration 675, Best Score: 2476.56
# Early stopping at iteration 734, Best Score: 2458.55
# Early stopping at iteration 669, Best Score: 2467.13
# Early stopping at iteration 606, Best Score: 2454.21
# Early stopping at iteration 576, Best Score: 2440.98
# Early stopping at iteration 642, Best Score: 2463.08
# Early stopping at iteration 580, Best Score: 2453.66
# Early stopping at iteration 866, Best Score: 2465.69
# Early stopping at iteration 596, Best Score: 2473.73
# Early stopping at iteration 592, Best Score: 2452.28
# Early stopping at iteration 744, Best Score: 2451.98
# Early stopping at iteration 606, Best Score: 2465.78
# Early stopping at iteration 695, Best Score: 2467.69
# Early stopping at iteration 723, Best Score: 2468.38
# Early stopping at iteration 692, Best Score: 2473.06
# Early stopping at iteration 873, Best Score: 2465.93
# Early stopping at iteration 706, Best Score: 2455.03
# Early stopping at iteration 676, Best Score: 2453.15
# Early stopping at iteration 640, Best Score: 2464.26
# Early stopping at iteration 669, Best Score: 2480.82
# Early stopping at iteration 557, Best Score: 2459.69
# Early stopping at iteration 701, Best Score: 2474.14
# Early stopping at iteration 878, Best Score: 2479.18
# Early stopping at iteration 565, Best Score: 2453.79
# Early stopping at iteration 553, Best Score: 2456.75
# Early stopping at iteration 776, Best Score: 2483.19
# Early stopping at iteration 703, Best Score: 2474.37
# Early stopping at iteration 533, Best Score: 2438.64
# Early stopping at iteration 760, Best Score: 2453.24
# Early stopping at iteration 647, Best Score: 2466.12
# Early stopping at iteration 634, Best Score: 2458.82
# Early stopping at iteration 565, Best Score: 2455.47
# Early stopping at iteration 556, Best Score: 2443.04
# Early stopping at iteration 523, Best Score: 2431.28
# Early stopping at iteration 612, Best Score: 2468.96
# Early stopping at iteration 662, Best Score: 2465.45
# Early stopping at iteration 568, Best Score: 2444.63
# Early stopping at iteration 648, Best Score: 2458.08
# Early stopping at iteration 776, Best Score: 2468.50
#   Deck Trial 200/250
# Early stopping at iteration 607, Best Score: 2458.92
# Early stopping at iteration 603, Best Score: 2446.32
# Early stopping at iteration 662, Best Score: 2450.79
# Early stopping at iteration 613, Best Score: 2449.19
# Early stopping at iteration 752, Best Score: 2473.63
# Early stopping at iteration 623, Best Score: 2448.75
# Early stopping at iteration 689, Best Score: 2484.20
# Early stopping at iteration 711, Best Score: 2466.42
# Early stopping at iteration 794, Best Score: 2459.84
# Early stopping at iteration 625, Best Score: 2459.26
# Early stopping at iteration 935, Best Score: 2474.80
# Early stopping at iteration 643, Best Score: 2454.91
# Early stopping at iteration 547, Best Score: 2455.59
# Early stopping at iteration 637, Best Score: 2460.13
# Early stopping at iteration 549, Best Score: 2447.76
# Early stopping at iteration 683, Best Score: 2470.26
# Early stopping at iteration 1274, Best Score: 2456.99
# Early stopping at iteration 543, Best Score: 2457.66
# Early stopping at iteration 565, Best Score: 2450.96
# Early stopping at iteration 810, Best Score: 2477.37
# Early stopping at iteration 657, Best Score: 2467.52
# Early stopping at iteration 642, Best Score: 2462.81
# Early stopping at iteration 658, Best Score: 2460.51
# Early stopping at iteration 932, Best Score: 2486.10
# Early stopping at iteration 597, Best Score: 2445.40
# Early stopping at iteration 735, Best Score: 2469.46
# Early stopping at iteration 744, Best Score: 2477.12
# Early stopping at iteration 746, Best Score: 2450.40
# Early stopping at iteration 632, Best Score: 2461.60
# Early stopping at iteration 633, Best Score: 2454.18
# Early stopping at iteration 719, Best Score: 2464.82
# Early stopping at iteration 537, Best Score: 2453.66
# Early stopping at iteration 557, Best Score: 2439.36
# Early stopping at iteration 641, Best Score: 2471.42
# Early stopping at iteration 563, Best Score: 2458.09
# Early stopping at iteration 720, Best Score: 2450.42
# Early stopping at iteration 623, Best Score: 2456.91
# Early stopping at iteration 659, Best Score: 2459.48
# Early stopping at iteration 624, Best Score: 2461.88
# Early stopping at iteration 619, Best Score: 2465.38
# Early stopping at iteration 866, Best Score: 2469.86
# Early stopping at iteration 701, Best Score: 2482.62
# Early stopping at iteration 571, Best Score: 2449.80
# Early stopping at iteration 580, Best Score: 2454.58
# Early stopping at iteration 550, Best Score: 2454.29
# Early stopping at iteration 626, Best Score: 2466.57
# Early stopping at iteration 617, Best Score: 2453.41
# Early stopping at iteration 590, Best Score: 2461.62
# Early stopping at iteration 812, Best Score: 2458.17
# Early stopping at iteration 677, Best Score: 2459.53
# Early stopping at iteration 582, Best Score: 2455.12
# GNN Trial 3 completed with 250 decks.
#
# GNN Trial 4/20
# Training GNN and building synergy matrix...
# Epoch 10/300 - Node Loss: 13.0729, Synergy Loss: 2.3755, Total: 17.8239
# Epoch 20/300 - Node Loss: 2.5446, Synergy Loss: 2.2435, Total: 7.0316
# Epoch 30/300 - Node Loss: 1.7455, Synergy Loss: 2.0804, Total: 5.9063
# Epoch 40/300 - Node Loss: 1.1239, Synergy Loss: 1.8776, Total: 4.8792
# Epoch 50/300 - Node Loss: 1.0285, Synergy Loss: 1.5506, Total: 4.1297
# Epoch 60/300 - Node Loss: 1.1096, Synergy Loss: 1.0599, Total: 3.2294
# Epoch 70/300 - Node Loss: 1.2070, Synergy Loss: 0.9598, Total: 3.1266
# Epoch 80/300 - Node Loss: 1.1976, Synergy Loss: 0.8131, Total: 2.8238
# Epoch 90/300 - Node Loss: 1.1839, Synergy Loss: 0.7901, Total: 2.7641
# Epoch 100/300 - Node Loss: 1.1810, Synergy Loss: 0.7590, Total: 2.6990
# Epoch 110/300 - Node Loss: 1.1192, Synergy Loss: 0.7453, Total: 2.6097
# Epoch 120/300 - Node Loss: 1.1575, Synergy Loss: 0.7092, Total: 2.5758
# Epoch 130/300 - Node Loss: 1.1543, Synergy Loss: 0.6456, Total: 2.4455
# Epoch 140/300 - Node Loss: 1.0364, Synergy Loss: 0.6816, Total: 2.3997
# Epoch 150/300 - Node Loss: 1.0496, Synergy Loss: 0.6356, Total: 2.3207
# Early stopping at epoch 159
# Existing model archived to: 20250310_104856_gnn_model_ST02-001.pth
# Model saved to: models\gnn_model_ST02-001.pth
# Early stopping at iteration 578, Best Score: 3139.17
# Early stopping at iteration 538, Best Score: 3087.54
# Early stopping at iteration 672, Best Score: 3174.91
# Early stopping at iteration 716, Best Score: 3177.21
# Early stopping at iteration 711, Best Score: 3164.09
# Early stopping at iteration 887, Best Score: 3162.88
# Early stopping at iteration 690, Best Score: 3155.63
# Early stopping at iteration 614, Best Score: 3135.75
# Early stopping at iteration 691, Best Score: 3144.82
# Early stopping at iteration 625, Best Score: 3166.51
# Early stopping at iteration 558, Best Score: 3116.55
# Early stopping at iteration 711, Best Score: 3196.09
# Early stopping at iteration 590, Best Score: 3136.00
# Early stopping at iteration 754, Best Score: 3134.71
# ...
# Early stopping at iteration 562, Best Score: 3104.01
# Early stopping at iteration 591, Best Score: 3202.48
# Early stopping at iteration 767, Best Score: 3275.48
# GNN Trial 19 completed with 250 decks.
#
# GNN Trial 20/20
# Training GNN and building synergy matrix...
# Epoch 10/300 - Node Loss: 41.9156, Synergy Loss: 1.9917, Total: 45.8991
# Epoch 20/300 - Node Loss: 8.8340, Synergy Loss: 1.8305, Total: 12.4950
# Epoch 30/300 - Node Loss: 2.7880, Synergy Loss: 1.7547, Total: 6.2974
# Epoch 40/300 - Node Loss: 1.4243, Synergy Loss: 1.6537, Total: 4.7316
# Epoch 50/300 - Node Loss: 1.0842, Synergy Loss: 1.5792, Total: 4.2426
# Epoch 60/300 - Node Loss: 1.0141, Synergy Loss: 1.5289, Total: 4.0720
# Epoch 70/300 - Node Loss: 1.0587, Synergy Loss: 1.4834, Total: 4.0254
# Epoch 80/300 - Node Loss: 1.0447, Synergy Loss: 1.4109, Total: 3.8665
# Epoch 90/300 - Node Loss: 1.0981, Synergy Loss: 1.3029, Total: 3.7038
# Epoch 100/300 - Node Loss: 1.0780, Synergy Loss: 1.1989, Total: 3.4759
# Epoch 110/300 - Node Loss: 1.1504, Synergy Loss: 1.0762, Total: 3.3029
# Epoch 120/300 - Node Loss: 1.3491, Synergy Loss: 0.8480, Total: 3.0450
# Epoch 130/300 - Node Loss: 1.4542, Synergy Loss: 0.7616, Total: 2.9773
# Epoch 140/300 - Node Loss: 1.2817, Synergy Loss: 0.6649, Total: 2.6115
# Epoch 150/300 - Node Loss: 1.3870, Synergy Loss: 0.6133, Total: 2.6136
# Epoch 160/300 - Node Loss: 1.3964, Synergy Loss: 0.5368, Total: 2.4700
# Epoch 170/300 - Node Loss: 1.3253, Synergy Loss: 0.5541, Total: 2.4334
# Epoch 180/300 - Node Loss: 1.5783, Synergy Loss: 0.4961, Total: 2.5705
# Epoch 190/300 - Node Loss: 1.3617, Synergy Loss: 0.4893, Total: 2.3404
# Epoch 200/300 - Node Loss: 1.4256, Synergy Loss: 0.4559, Total: 2.3374
# Epoch 210/300 - Node Loss: 1.3409, Synergy Loss: 0.4368, Total: 2.2144
# Epoch 220/300 - Node Loss: 1.1966, Synergy Loss: 0.4413, Total: 2.0791
# Epoch 230/300 - Node Loss: 1.2405, Synergy Loss: 0.4020, Total: 2.0445
# Epoch 240/300 - Node Loss: 1.2640, Synergy Loss: 0.4083, Total: 2.0806
# Epoch 250/300 - Node Loss: 1.2684, Synergy Loss: 0.3313, Total: 1.9310
# Epoch 260/300 - Node Loss: 1.3110, Synergy Loss: 0.3162, Total: 1.9434
# Epoch 270/300 - Node Loss: 1.1968, Synergy Loss: 0.2830, Total: 1.7627
# Epoch 280/300 - Node Loss: 1.1568, Synergy Loss: 0.2673, Total: 1.6913
# Epoch 290/300 - Node Loss: 1.1557, Synergy Loss: 0.2493, Total: 1.6544
# Epoch 300/300 - Node Loss: 1.1529, Synergy Loss: 0.2356, Total: 1.6242
# Existing model archived to: 20250310_204628_gnn_model_OP08-098.pth
# Model saved to: models\gnn_model_OP08-098.pth
# Early stopping at iteration 599, Best Score: 3042.93
# Early stopping at iteration 608, Best Score: 3055.03
# Early stopping at iteration 679, Best Score: 3097.41
# Early stopping at iteration 671, Best Score: 3138.31
# Early stopping at iteration 578, Best Score: 2995.66
# Early stopping at iteration 634, Best Score: 3007.31
# Early stopping at iteration 634, Best Score: 3117.33
# Early stopping at iteration 877, Best Score: 3119.98
# Early stopping at iteration 779, Best Score: 3151.95
# Early stopping at iteration 841, Best Score: 3084.93
# Early stopping at iteration 588, Best Score: 3031.61
# Early stopping at iteration 592, Best Score: 3050.88
# Early stopping at iteration 909, Best Score: 3115.43
# Early stopping at iteration 885, Best Score: 3018.35
# Early stopping at iteration 664, Best Score: 3074.89
# Early stopping at iteration 652, Best Score: 3077.11
# Early stopping at iteration 627, Best Score: 3127.56
# Early stopping at iteration 746, Best Score: 3136.31
# Early stopping at iteration 649, Best Score: 3038.69
# Early stopping at iteration 652, Best Score: 3110.50
# Early stopping at iteration 718, Best Score: 3097.31
# Early stopping at iteration 696, Best Score: 3117.43
# Early stopping at iteration 680, Best Score: 3020.37
# Early stopping at iteration 605, Best Score: 3053.94
# Early stopping at iteration 812, Best Score: 3145.51
# Early stopping at iteration 630, Best Score: 3055.12
# Early stopping at iteration 614, Best Score: 3068.88
# Early stopping at iteration 580, Best Score: 2987.75
# Early stopping at iteration 571, Best Score: 2978.05
# Early stopping at iteration 691, Best Score: 3110.05
# Early stopping at iteration 561, Best Score: 2935.75
# Early stopping at iteration 955, Best Score: 3144.12
# Early stopping at iteration 821, Best Score: 3090.72
# Early stopping at iteration 809, Best Score: 3129.55
# Early stopping at iteration 542, Best Score: 2949.41
# Early stopping at iteration 549, Best Score: 2974.70
# Early stopping at iteration 500, Best Score: 2828.46
# Early stopping at iteration 624, Best Score: 3057.08
# Early stopping at iteration 609, Best Score: 3081.16
# Early stopping at iteration 653, Best Score: 3018.23
# Early stopping at iteration 919, Best Score: 3152.63
# Early stopping at iteration 774, Best Score: 3097.19
# Early stopping at iteration 730, Best Score: 3125.79
# Early stopping at iteration 774, Best Score: 3137.63
# Early stopping at iteration 648, Best Score: 3087.38
# Early stopping at iteration 613, Best Score: 3080.51
# Early stopping at iteration 707, Best Score: 3145.69
# Early stopping at iteration 806, Best Score: 3135.37
# Early stopping at iteration 519, Best Score: 2877.74
# Early stopping at iteration 710, Best Score: 2991.30
# Early stopping at iteration 747, Best Score: 3141.82
# Early stopping at iteration 785, Best Score: 3131.53
# Early stopping at iteration 969, Best Score: 3123.45
# Early stopping at iteration 583, Best Score: 3007.52
# Early stopping at iteration 902, Best Score: 3006.65
# Early stopping at iteration 500, Best Score: 2828.46
# Early stopping at iteration 591, Best Score: 3030.78
# Early stopping at iteration 942, Best Score: 3039.61
# Early stopping at iteration 539, Best Score: 2867.49
# Early stopping at iteration 573, Best Score: 3030.19
# Early stopping at iteration 768, Best Score: 3075.40
# Early stopping at iteration 821, Best Score: 3154.43
# Early stopping at iteration 679, Best Score: 3047.53
# Early stopping at iteration 1198, Best Score: 3149.06
# Early stopping at iteration 500, Best Score: 2828.46
# Early stopping at iteration 540, Best Score: 2983.46
# Early stopping at iteration 631, Best Score: 3020.01
# Early stopping at iteration 691, Best Score: 3069.96
# Early stopping at iteration 797, Best Score: 3144.38
# Early stopping at iteration 887, Best Score: 3102.00
# Early stopping at iteration 599, Best Score: 3043.69
# Early stopping at iteration 892, Best Score: 3013.74
# Early stopping at iteration 545, Best Score: 2884.03
# Early stopping at iteration 685, Best Score: 3103.50
# Early stopping at iteration 761, Best Score: 3136.20
# Early stopping at iteration 616, Best Score: 2915.87
# Early stopping at iteration 536, Best Score: 2920.54
# Early stopping at iteration 868, Best Score: 3140.32
# Early stopping at iteration 750, Best Score: 3079.09
# Early stopping at iteration 740, Best Score: 2988.71
# Early stopping at iteration 752, Best Score: 3132.87
# Early stopping at iteration 585, Best Score: 2854.01
# Early stopping at iteration 970, Best Score: 3002.46
# Early stopping at iteration 724, Best Score: 3118.96
# Early stopping at iteration 544, Best Score: 2909.85
# Early stopping at iteration 622, Best Score: 3047.68
# Early stopping at iteration 901, Best Score: 2927.37
# Early stopping at iteration 813, Best Score: 3070.91
# Early stopping at iteration 624, Best Score: 3086.16
# Early stopping at iteration 542, Best Score: 2974.70
# Early stopping at iteration 562, Best Score: 2996.50
# Early stopping at iteration 559, Best Score: 3000.27
# Early stopping at iteration 631, Best Score: 3125.50
# Early stopping at iteration 688, Best Score: 3074.30
# Early stopping at iteration 783, Best Score: 3093.33
# Early stopping at iteration 1163, Best Score: 3104.65
# Early stopping at iteration 689, Best Score: 3060.92
# Early stopping at iteration 500, Best Score: 2828.46
# Early stopping at iteration 647, Best Score: 3028.95
#   Deck Trial 100/250
# Early stopping at iteration 588, Best Score: 3035.44
# Early stopping at iteration 589, Best Score: 3050.49
# Early stopping at iteration 677, Best Score: 3112.63
# Early stopping at iteration 526, Best Score: 2871.51
# Early stopping at iteration 560, Best Score: 2956.71
# Early stopping at iteration 739, Best Score: 3147.76
# Early stopping at iteration 721, Best Score: 3113.15
# Early stopping at iteration 752, Best Score: 3131.56
# Early stopping at iteration 697, Best Score: 3115.30
# Early stopping at iteration 563, Best Score: 2947.05
# Early stopping at iteration 796, Best Score: 3114.13
# Early stopping at iteration 650, Best Score: 3067.76
# Early stopping at iteration 717, Best Score: 3086.74
# Early stopping at iteration 611, Best Score: 3024.52
# Early stopping at iteration 599, Best Score: 3047.42
# Early stopping at iteration 769, Best Score: 3106.42
# Early stopping at iteration 716, Best Score: 3103.93
# Early stopping at iteration 759, Best Score: 3127.65
# Early stopping at iteration 567, Best Score: 2938.75
# Early stopping at iteration 560, Best Score: 2912.75
# Early stopping at iteration 662, Best Score: 3113.95
# Early stopping at iteration 757, Best Score: 3089.33
# Early stopping at iteration 721, Best Score: 3112.34
# Early stopping at iteration 918, Best Score: 3152.44
# Early stopping at iteration 847, Best Score: 3142.06
# Early stopping at iteration 597, Best Score: 3026.40
# Early stopping at iteration 989, Best Score: 3139.08
# Early stopping at iteration 617, Best Score: 2984.23
# Early stopping at iteration 794, Best Score: 3133.14
# Early stopping at iteration 507, Best Score: 2872.93
# Early stopping at iteration 591, Best Score: 3044.25
# Early stopping at iteration 574, Best Score: 2959.44
# Early stopping at iteration 648, Best Score: 3102.32
# Early stopping at iteration 656, Best Score: 2985.45
# Early stopping at iteration 542, Best Score: 2973.16
# Early stopping at iteration 632, Best Score: 3073.72
# Early stopping at iteration 599, Best Score: 3044.21
# Early stopping at iteration 1073, Best Score: 3128.87
# Early stopping at iteration 1000, Best Score: 3146.38
# Early stopping at iteration 901, Best Score: 3159.20
# Early stopping at iteration 588, Best Score: 2993.51
# Early stopping at iteration 621, Best Score: 2975.46
# Early stopping at iteration 756, Best Score: 3128.18
# Early stopping at iteration 701, Best Score: 3091.17
# Early stopping at iteration 872, Best Score: 3159.20
# Early stopping at iteration 546, Best Score: 3018.33
# Early stopping at iteration 509, Best Score: 2876.33
# Early stopping at iteration 661, Best Score: 3083.10
# Early stopping at iteration 598, Best Score: 2982.25
# Early stopping at iteration 893, Best Score: 3112.06
# Early stopping at iteration 605, Best Score: 3044.29
# Early stopping at iteration 713, Best Score: 3134.93
# Early stopping at iteration 578, Best Score: 3006.14
# Early stopping at iteration 828, Best Score: 3015.80
# Early stopping at iteration 790, Best Score: 3109.07
# Early stopping at iteration 773, Best Score: 3116.78
# Early stopping at iteration 852, Best Score: 3123.49
# Early stopping at iteration 867, Best Score: 3140.31
# Early stopping at iteration 991, Best Score: 3087.27
# Early stopping at iteration 581, Best Score: 2965.37
# Early stopping at iteration 809, Best Score: 3130.23
# Early stopping at iteration 644, Best Score: 3032.95
# Early stopping at iteration 702, Best Score: 3103.48
# Early stopping at iteration 686, Best Score: 3109.56
# Early stopping at iteration 593, Best Score: 3026.36
# Early stopping at iteration 593, Best Score: 3057.65
# Early stopping at iteration 500, Best Score: 2828.46
# Early stopping at iteration 575, Best Score: 2933.29
# Early stopping at iteration 1026, Best Score: 3068.87
# Early stopping at iteration 643, Best Score: 3072.65
# Early stopping at iteration 529, Best Score: 2891.68
# Early stopping at iteration 725, Best Score: 3121.36
# Early stopping at iteration 636, Best Score: 3036.01
# Early stopping at iteration 578, Best Score: 2890.46
# Early stopping at iteration 543, Best Score: 2977.93
# Early stopping at iteration 545, Best Score: 2937.46
# Early stopping at iteration 605, Best Score: 3039.92
# Early stopping at iteration 896, Best Score: 3130.39
# Early stopping at iteration 714, Best Score: 3132.25
# Early stopping at iteration 632, Best Score: 3099.24
# Early stopping at iteration 681, Best Score: 3092.42
# Early stopping at iteration 532, Best Score: 2866.37
# Early stopping at iteration 809, Best Score: 3121.47
# Early stopping at iteration 794, Best Score: 3089.77
# Early stopping at iteration 730, Best Score: 3010.97
# Early stopping at iteration 694, Best Score: 3096.47
# Early stopping at iteration 532, Best Score: 2845.67
# Early stopping at iteration 799, Best Score: 3130.95
# Early stopping at iteration 726, Best Score: 3123.31
# Early stopping at iteration 961, Best Score: 3146.12
# Early stopping at iteration 566, Best Score: 2936.27
# Early stopping at iteration 771, Best Score: 3145.06
# Early stopping at iteration 546, Best Score: 2976.23
# Early stopping at iteration 500, Best Score: 2828.46
# Early stopping at iteration 500, Best Score: 2828.46
# Early stopping at iteration 853, Best Score: 3120.88
# Early stopping at iteration 601, Best Score: 2971.61
# Early stopping at iteration 659, Best Score: 3104.15
# Early stopping at iteration 702, Best Score: 3133.63
# Early stopping at iteration 674, Best Score: 3119.40
#   Deck Trial 200/250
# Early stopping at iteration 686, Best Score: 3064.15
# Early stopping at iteration 554, Best Score: 2968.83
# Early stopping at iteration 558, Best Score: 3003.13
# Early stopping at iteration 628, Best Score: 2956.94
# Early stopping at iteration 967, Best Score: 3154.44
# Early stopping at iteration 650, Best Score: 3104.58
# Early stopping at iteration 526, Best Score: 2852.46
# Early stopping at iteration 727, Best Score: 3108.23
# Early stopping at iteration 584, Best Score: 3000.34
# Early stopping at iteration 727, Best Score: 3080.73
# Early stopping at iteration 640, Best Score: 3077.36
# Early stopping at iteration 587, Best Score: 3040.51
# Early stopping at iteration 500, Best Score: 2828.46
# Early stopping at iteration 762, Best Score: 3138.93
# Early stopping at iteration 756, Best Score: 3133.63
# Early stopping at iteration 585, Best Score: 3056.97
# Early stopping at iteration 956, Best Score: 3134.69
# Early stopping at iteration 593, Best Score: 3066.96
# Early stopping at iteration 839, Best Score: 3054.35
# Early stopping at iteration 742, Best Score: 3093.16
# Early stopping at iteration 516, Best Score: 2916.52
# Early stopping at iteration 1205, Best Score: 3145.89
# Early stopping at iteration 687, Best Score: 3096.00
# Early stopping at iteration 702, Best Score: 3095.84
# Early stopping at iteration 531, Best Score: 2889.62
# Early stopping at iteration 838, Best Score: 2921.20
# Early stopping at iteration 648, Best Score: 3069.30
# Early stopping at iteration 754, Best Score: 3141.00
# Early stopping at iteration 673, Best Score: 3111.37
# Early stopping at iteration 606, Best Score: 2966.40
# Early stopping at iteration 637, Best Score: 3007.02
# Early stopping at iteration 864, Best Score: 3151.50
# Early stopping at iteration 811, Best Score: 3067.30
# Early stopping at iteration 711, Best Score: 3136.32
# Early stopping at iteration 646, Best Score: 3070.73
# Early stopping at iteration 607, Best Score: 3061.30
# Early stopping at iteration 758, Best Score: 3085.85
# Early stopping at iteration 500, Best Score: 2828.46
# Early stopping at iteration 790, Best Score: 3141.00
# Early stopping at iteration 500, Best Score: 2828.46
# Early stopping at iteration 597, Best Score: 3026.86
# Early stopping at iteration 747, Best Score: 3114.40
# Early stopping at iteration 629, Best Score: 3069.60
# Early stopping at iteration 668, Best Score: 3109.79
# Early stopping at iteration 716, Best Score: 3135.61
# Early stopping at iteration 1079, Best Score: 2997.39
# Early stopping at iteration 700, Best Score: 3124.67
# Early stopping at iteration 769, Best Score: 3078.59
# Early stopping at iteration 502, Best Score: 2848.98
# Early stopping at iteration 690, Best Score: 3123.12
# Early stopping at iteration 526, Best Score: 2916.70
# GNN Trial 20 completed with 250 decks.
# Evaluations for OP08-098 completed. Results saved in evaluations\OP08-098
#
# All evaluations completed. Results are stored in the 'evaluations' directory.

# %%
import pandas as pd
from itertools import combinations
from copy import deepcopy

# %%
EVAL_DIR = "evaluations"

# %%
def load_evaluation_decks(leader_id):
    """
    Liest 'all_trials.json' für den Leader und gibt DataFrame zurück,
    mit Spalten:
    - leader, gnn_trial, deck_trial
    - score, meta_overlap, avg_synergy, num_singletons
    - deck_size
    """
    path = os.path.join(EVAL_DIR, leader_id, "all_trials.json")
    if not os.path.exists(path):
        return pd.DataFrame()
    with open(path,"r") as f:
        data = json.load(f)
    rows=[]
    for trial_info in data:
        gnn_trial = trial_info["gnn_trial"]
        for deck_res in trial_info["deck_results"]:
            dt = deck_res["deck_trial"]
            sc = deck_res["score"]
            mo = deck_res["meta_overlap"]
            avs= deck_res["avg_synergy"]
            ns = deck_res["num_singletons"]
            deck_data = deck_res["deck"]  # dict {card_id:count}
            deck_size = sum(deck_data.values())
            rows.append({
                "leader": leader_id,
                "gnn_trial": gnn_trial,
                "deck_trial": dt,
                "score": sc,
                "meta_overlap": mo,
                "avg_synergy": avs,
                "num_singletons": ns,
                "deck_size": deck_size
            })
    return pd.DataFrame(rows)

# %%
# "OP01-001", # Roronoa Zoro Aggro
#"ST02-001", # Eustass Kid Midrange
#"ST13-003", # Monkey D. Luffy Combo
#"OP07-079", # Lucci Control
#"OP08-098" # Kalgara Midrange OP08
trial_models = {
    "OP01-001": {
        1: "models/archive/20250310_020344_gnn_model_OP01-001.pth",
        2: "models/archive/20250310_020841_gnn_model_OP01-001.pth",
        3: "models/archive/20250310_021402_gnn_model_OP01-001.pth",
        4: "models/archive/20250310_021918_gnn_model_OP01-001.pth",
        5: "models/archive/20250310_022357_gnn_model_OP01-001.pth",
        6: "models/archive/20250310_022638_gnn_model_OP01-001.pth",
        7: "models/archive/20250310_023122_gnn_model_OP01-001.pth",
        8: "models/archive/20250310_023535_gnn_model_OP01-001.pth",
        9: "models/archive/20250310_023934_gnn_model_OP01-001.pth",
        10: "models/archive/20250310_024405_gnn_model_OP01-001.pth",
        11: "models/archive/20250310_024911_gnn_model_OP01-001.pth",
        12: "models/archive/20250310_025427_gnn_model_OP01-001.pth",
        13: "models/archive/20250310_092915_gnn_model_OP01-001.pth",
        14: "models/archive/20250310_093400_gnn_model_OP01-001.pth",
        15: "models/archive/20250310_093846_gnn_model_OP01-001.pth",
        16: "models/archive/20250310_094344_gnn_model_OP01-001.pth",
        17: "models/archive/20250310_094848_gnn_model_OP01-001.pth",
        18: "models/archive/20250310_095356_gnn_model_OP01-001.pth",
        19: "models/archive/20250310_095802_gnn_model_OP01-001.pth",
        20: "models/gnn_model_OP01-001.pth"
    },
    "ST02-001": {
        1: "models/archive/20250310_103954_gnn_model_ST02-001.pth",
        2: "models/archive/20250310_104430_gnn_model_ST02-001.pth",
        3: "models/archive/20250310_104856_gnn_model_ST02-001.pth",
        4: "models/archive/20250310_105312_gnn_model_ST02-001.pth",
        5: "models/archive/20250310_105928_gnn_model_ST02-001.pth",
        6: "models/archive/20250310_110312_gnn_model_ST02-001.pth",
        7: "models/archive/20250310_110844_gnn_model_ST02-001.pth",
        8: "models/archive/20250310_111152_gnn_model_ST02-001.pth",
        9: "models/archive/20250310_111730_gnn_model_ST02-001.pth",
        10: "models/archive/20250310_112328_gnn_model_ST02-001.pth",
        11: "models/archive/20250310_112748_gnn_model_ST02-001.pth",
        12: "models/archive/20250310_113235_gnn_model_ST02-001.pth",
        13: "models/archive/20250310_113852_gnn_model_ST02-001.pth",
        14: "models/archive/20250310_114537_gnn_model_ST02-001.pth",
        15: "models/archive/20250310_114905_gnn_model_ST02-001.pth",
        16: "models/archive/20250310_115601_gnn_model_ST02-001.pth",
        17: "models/archive/20250310_120249_gnn_model_ST02-001.pth",
        18: "models/archive/20250310_120930_gnn_model_ST02-001.pth",
        19: "models/archive/20250310_121534_gnn_model_ST02-001.pth",
        20: "models/gnn_model_ST02-001.pth"
    },
    "ST13-003": {
        1: "models/archive/20250310_124906_gnn_model_ST13-003.pth",
        2: "models/archive/20250310_130357_gnn_model_ST13-003.pth",
        3: "models/archive/20250310_131251_gnn_model_ST13-003.pth",
        4: "models/archive/20250310_132633_gnn_model_ST13-003.pth",
        5: "models/archive/20250310_134640_gnn_model_ST13-003.pth",
        6: "models/archive/20250310_140535_gnn_model_ST13-003.pth",
        7: "models/archive/20250310_142354_gnn_model_ST13-003.pth",
        8: "models/archive/20250310_144243_gnn_model_ST13-003.pth",
        9: "models/archive/20250310_150000_gnn_model_ST13-003.pth",
        10: "models/archive/20250310_151659_gnn_model_ST13-003.pth",
        11: "models/archive/20250310_153450_gnn_model_ST13-003.pth",
        12: "models/archive/20250310_155124_gnn_model_ST13-003.pth",
        13: "models/archive/20250310_160222_gnn_model_ST13-003.pth",
        14: "models/archive/20250310_161823_gnn_model_ST13-003.pth",
        15: "models/archive/20250310_162924_gnn_model_ST13-003.pth",
        16: "models/archive/20250310_163821_gnn_model_ST13-003.pth",
        17: "models/archive/20250310_164728_gnn_model_ST13-003.pth",
        18: "models/archive/20250310_170323_gnn_model_ST13-003.pth",
        19: "models/archive/20250310_171913_gnn_model_ST13-003.pth",
        20: "models/gnn_model_ST13-003.pth"
    },
    "OP07-079": {
        1: "models/archive/20250310_172729_gnn_model_OP07-079.pth",
        2: "models/archive/20250310_173145_gnn_model_OP07-079.pth",
        3: "models/archive/20250310_173602_gnn_model_OP07-079.pth",
        4: "models/archive/20250310_174026_gnn_model_OP07-079.pth",
        5: "models/archive/20250310_174414_gnn_model_OP07-079.pth",
        6: "models/archive/20250310_174837_gnn_model_OP07-079.pth",
        7: "models/archive/20250310_175230_gnn_model_OP07-079.pth",
        8: "models/archive/20250310_175541_gnn_model_OP07-079.pth",
        9: "models/archive/20250310_180005_gnn_model_OP07-079.pth",
        10: "models/archive/20250310_180252_gnn_model_OP07-079.pth",
        11: "models/archive/20250310_180633_gnn_model_OP07-079.pth",
        12: "models/archive/20250310_181033_gnn_model_OP07-079.pth",
        13: "models/archive/20250310_181501_gnn_model_OP07-079.pth",
        14: "models/archive/20250310_182015_gnn_model_OP07-079.pth",
        15: "models/archive/20250310_182453_gnn_model_OP07-079.pth",
        16: "models/archive/20250310_183141_gnn_model_OP07-079.pth",
        17: "models/archive/20250310_183437_gnn_model_OP07-079.pth",
        18: "models/archive/20250310_183954_gnn_model_OP07-079.pth",
        19: "models/archive/20250310_184357_gnn_model_OP07-079.pth",
        20: "models/gnn_model_OP07-079.pth"
    },
    "OP08-098": {
        1: "models/archive/20250310_185753_gnn_model_OP08-098.pth",
        2: "models/archive/20250310_190439_gnn_model_OP08-098.pth",
        3: "models/archive/20250310_191003_gnn_model_OP08-098.pth",
        4: "models/archive/20250310_191656_gnn_model_OP08-098.pth",
        5: "models/archive/20250310_192424_gnn_model_OP08-098.pth",
        6: "models/archive/20250310_192859_gnn_model_OP08-098.pth",
        7: "models/archive/20250310_193330_gnn_model_OP08-098.pth",
        8: "models/archive/20250310_193956_gnn_model_OP08-098.pth",
        9: "models/archive/20250310_194628_gnn_model_OP08-098.pth",
        10: "models/archive/20250310_195245_gnn_model_OP08-098.pth",
        11: "models/archive/20250310_195925_gnn_model_OP08-098.pth",
        12: "models/archive/20250310_200550_gnn_model_OP08-098.pth",
        13: "models/archive/20250310_201122_gnn_model_OP08-098.pth",
        14: "models/archive/20250310_201736_gnn_model_OP08-098.pth",
        15: "models/archive/20250310_202108_gnn_model_OP08-098.pth",
        16: "models/archive/20250310_202725_gnn_model_OP08-098.pth",
        17: "models/archive/20250310_203324_gnn_model_OP08-098.pth",
        18: "models/archive/20250310_203938_gnn_model_OP08-098.pth",
        19: "models/archive/20250310_204628_gnn_model_OP08-098.pth",
        20: "models/gnn_model_OP08-098.pth"
    }
}

# %%
leaders_present = [d for d in os.listdir(EVAL_DIR) 
                   if os.path.isdir(os.path.join(EVAL_DIR,d))]

all_rows = []

for leader_id in leaders_present:
    # read evaluation data
    df_decks = load_evaluation_decks(leader_id)
    if df_decks.empty:
        print(f"[WARN] Keine deck evaluation für leader {leader_id}")
        continue
    
    # extract unique trials
    unique_trials = sorted(df_decks["gnn_trial"].unique())

    
    # leader card
    lcard = next((c for c in leaders if c["id"]==leader_id), None)
    if not lcard:
        print(f"[ERROR] Leader-card {leader_id} missing.")
        synergy_rows.append({"leader": leader_id,"gnn_trial":tr,
                                "synergy_mse": None})
        continue
    
    # relevant decks
    leader_color = set(get_card_colors(lcard))
    leader_arche = lcard.get("archetype","").strip()
    
    
    relevant_decks = gather_decks_for_color_archetype(leader_color, leader_arche, decks_data) or decks_data
    known_edges = parse_known_synergies(known_synergies_data, synergy_weight=5.0)
    synergy_graph = build_synergy_graph(relevant_decks, leader_arche, leader_color,
                                        synergy_weight=2.0,
                                        known_synergy_edges=known_edges)
    freq_map  = compute_card_frequency(relevant_decks)
    usage_map = compute_archetype_usage_ratio(relevant_decks, leader_arche)
    
    # PyG
    data_pyg, _ = build_pyg_data(cards_data, synergy_graph, freq_map, usage_map)
    
    in_dim = data_pyg.x.shape[1]
    
    synergy_rows = []
    for tr in unique_trials:
        # path to model file
        model_file = None
        # check if model file exists
        if leader_id in trial_models and tr in trial_models[leader_id]:
            model_file = trial_models[leader_id][tr]
        else:
            pass
        
        if model_file is None or (not os.path.exists(model_file)):
            print(f"[WARN] Leader={leader_id}, trial={tr}: no model file found.")
            synergy_rows.append({"leader": leader_id, "gnn_trial": tr,
                                 "synergy_mse": None})
            continue
        
        # model
        model = MultiTaskGNN(in_dim=in_dim, hidden_dim=128, emb_dim=64, dropout=0.5, num_layers=4)
        model = load_model(model, model_file)
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        model.to(device)
        
        # synergy
        print(f"Calculating synergy for leader {leader_id}, trial {tr}...")
        synergy_mse = evaluate_synergy_prediction_accuracy(model, data_pyg, known_edges)
        synergy_rows.append({"leader": leader_id,
                             "gnn_trial": tr,
                             "synergy_mse": synergy_mse})
    
    df_synergy = pd.DataFrame(synergy_rows)
    # Merge synergy->df_decks
    df_merged = pd.merge(df_decks, df_synergy, how="left", 
                         on=["leader","gnn_trial"])
    all_rows.append(df_merged)

df_final = pd.concat(all_rows, ignore_index=True) if all_rows else pd.DataFrame()


if not df_final.empty:
    # synergy_mse does only exist once per leader trail
    # 250 deck trials per leader trail
    corr_sm = df_final["synergy_mse"].corr(df_final["score"])
    print(f"Correlation synergy_mse <-> score (all leaders): {corr_sm:.3f}")

    # correlation per leader
    for ld in df_final["leader"].unique():
        sub = df_final[df_final["leader"]==ld]
        cc = sub["synergy_mse"].corr(sub["score"])
        print(f"Leader {ld}: corr(synergy_mse, score)={cc:.3f}")

    df_final.to_csv("evaluations/df_final.csv", index=False)
# Out:
# C:\Users\sandr\AppData\Local\Temp\ipykernel_756\921432365.py:14: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:257.)
#   x_tensor = torch.tensor(node_features, dtype=torch.float)
# Model loaded from: models/archive/20250310_020344_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 1...
# Synergy Prediction MSE on Known Edges: 1.7926
# Model loaded from: models/archive/20250310_020841_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 2...
# Synergy Prediction MSE on Known Edges: 1.4202
# Model loaded from: models/archive/20250310_021402_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 3...
# Synergy Prediction MSE on Known Edges: 2.0644
# Model loaded from: models/archive/20250310_021918_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 4...
# Synergy Prediction MSE on Known Edges: 2.5471
# Model loaded from: models/archive/20250310_022357_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 5...
# Synergy Prediction MSE on Known Edges: 1.9821
# Model loaded from: models/archive/20250310_022638_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 6...
# Synergy Prediction MSE on Known Edges: 2.0189
# Model loaded from: models/archive/20250310_023122_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 7...
# Synergy Prediction MSE on Known Edges: 0.9006
# Model loaded from: models/archive/20250310_023535_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 8...
# Synergy Prediction MSE on Known Edges: 1.8362
# Model loaded from: models/archive/20250310_023934_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 9...
# Synergy Prediction MSE on Known Edges: 2.2550
# Model loaded from: models/archive/20250310_024405_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 10...
# Synergy Prediction MSE on Known Edges: 2.6229
# Model loaded from: models/archive/20250310_024911_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 11...
# Synergy Prediction MSE on Known Edges: 1.6572
# Model loaded from: models/archive/20250310_025427_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 12...
# Synergy Prediction MSE on Known Edges: 2.4819
# Model loaded from: models/archive/20250310_092915_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 13...
# Synergy Prediction MSE on Known Edges: 1.6547
# Model loaded from: models/archive/20250310_093400_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 14...
# Synergy Prediction MSE on Known Edges: 0.8953
# Model loaded from: models/archive/20250310_093846_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 15...
# Synergy Prediction MSE on Known Edges: 1.6704
# Model loaded from: models/archive/20250310_094344_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 16...
# Synergy Prediction MSE on Known Edges: 2.2351
# Model loaded from: models/archive/20250310_094848_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 17...
# Synergy Prediction MSE on Known Edges: 3.2601
# Model loaded from: models/archive/20250310_095356_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 18...
# Synergy Prediction MSE on Known Edges: 1.6077
# Model loaded from: models/archive/20250310_095802_gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 19...
# Synergy Prediction MSE on Known Edges: 2.4294
# Model loaded from: models/gnn_model_OP01-001.pth
# Calculating synergy for leader OP01-001, trial 20...
# Synergy Prediction MSE on Known Edges: 1.5036
# Model loaded from: models/archive/20250310_172729_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 1...
# Synergy Prediction MSE on Known Edges: 1.8194
# Model loaded from: models/archive/20250310_173145_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 2...
# Synergy Prediction MSE on Known Edges: 1.3240
# Model loaded from: models/archive/20250310_173602_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 3...
# Synergy Prediction MSE on Known Edges: 1.8784
# Model loaded from: models/archive/20250310_174026_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 4...
# Synergy Prediction MSE on Known Edges: 1.9312
# Model loaded from: models/archive/20250310_174414_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 5...
# Synergy Prediction MSE on Known Edges: 2.2296
# Model loaded from: models/archive/20250310_174837_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 6...
# Synergy Prediction MSE on Known Edges: 1.3728
# Model loaded from: models/archive/20250310_175230_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 7...
# Synergy Prediction MSE on Known Edges: 2.0804
# Model loaded from: models/archive/20250310_175541_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 8...
# Synergy Prediction MSE on Known Edges: 2.3399
# Model loaded from: models/archive/20250310_180005_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 9...
# Synergy Prediction MSE on Known Edges: 1.6031
# Model loaded from: models/archive/20250310_180252_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 10...
# Synergy Prediction MSE on Known Edges: 1.8397
# Model loaded from: models/archive/20250310_180633_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 11...
# Synergy Prediction MSE on Known Edges: 1.6213
# Model loaded from: models/archive/20250310_181033_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 12...
# Synergy Prediction MSE on Known Edges: 1.8905
# Model loaded from: models/archive/20250310_181501_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 13...
# Synergy Prediction MSE on Known Edges: 2.0505
# Model loaded from: models/archive/20250310_182015_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 14...
# Synergy Prediction MSE on Known Edges: 1.7803
# Model loaded from: models/archive/20250310_182453_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 15...
# Synergy Prediction MSE on Known Edges: 1.4891
# Model loaded from: models/archive/20250310_183141_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 16...
# Synergy Prediction MSE on Known Edges: 1.8617
# Model loaded from: models/archive/20250310_183437_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 17...
# Synergy Prediction MSE on Known Edges: 2.4698
# Model loaded from: models/archive/20250310_183954_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 18...
# Synergy Prediction MSE on Known Edges: 0.7700
# Model loaded from: models/archive/20250310_184357_gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 19...
# Synergy Prediction MSE on Known Edges: 1.5134
# Model loaded from: models/gnn_model_OP07-079.pth
# Calculating synergy for leader OP07-079, trial 20...
# Synergy Prediction MSE on Known Edges: 1.5611
# Model loaded from: models/archive/20250310_185753_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 1...
# Synergy Prediction MSE on Known Edges: 1.4666
# Model loaded from: models/archive/20250310_190439_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 2...
# Synergy Prediction MSE on Known Edges: 1.8147
# Model loaded from: models/archive/20250310_191003_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 3...
# Synergy Prediction MSE on Known Edges: 1.6981
# Model loaded from: models/archive/20250310_191656_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 4...
# Synergy Prediction MSE on Known Edges: 1.5912
# Model loaded from: models/archive/20250310_192424_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 5...
# Synergy Prediction MSE on Known Edges: 1.7158
# Model loaded from: models/archive/20250310_192859_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 6...
# Synergy Prediction MSE on Known Edges: 1.8002
# Model loaded from: models/archive/20250310_193330_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 7...
# Synergy Prediction MSE on Known Edges: 1.7033
# Model loaded from: models/archive/20250310_193956_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 8...
# Synergy Prediction MSE on Known Edges: 1.6766
# Model loaded from: models/archive/20250310_194628_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 9...
# Synergy Prediction MSE on Known Edges: 1.4308
# Model loaded from: models/archive/20250310_195245_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 10...
# Synergy Prediction MSE on Known Edges: 1.7594
# Model loaded from: models/archive/20250310_195925_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 11...
# Synergy Prediction MSE on Known Edges: 1.7400
# Model loaded from: models/archive/20250310_200550_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 12...
# Synergy Prediction MSE on Known Edges: 1.7675
# Model loaded from: models/archive/20250310_201122_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 13...
# Synergy Prediction MSE on Known Edges: 1.7731
# Model loaded from: models/archive/20250310_201736_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 14...
# Synergy Prediction MSE on Known Edges: 1.5294
# Model loaded from: models/archive/20250310_202108_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 15...
# Synergy Prediction MSE on Known Edges: 1.6524
# Model loaded from: models/archive/20250310_202725_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 16...
# Synergy Prediction MSE on Known Edges: 1.0171
# Model loaded from: models/archive/20250310_203324_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 17...
# Synergy Prediction MSE on Known Edges: 1.3934
# Model loaded from: models/archive/20250310_203938_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 18...
# Synergy Prediction MSE on Known Edges: 1.5869
# Model loaded from: models/archive/20250310_204628_gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 19...
# Synergy Prediction MSE on Known Edges: 1.7789
# Model loaded from: models/gnn_model_OP08-098.pth
# Calculating synergy for leader OP08-098, trial 20...
# Synergy Prediction MSE on Known Edges: 1.6884
# Model loaded from: models/archive/20250310_103954_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 1...
# Synergy Prediction MSE on Known Edges: 1.7888
# Model loaded from: models/archive/20250310_104430_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 2...
# Synergy Prediction MSE on Known Edges: 1.6935
# Model loaded from: models/archive/20250310_104856_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 3...
# Synergy Prediction MSE on Known Edges: 1.4627
# Model loaded from: models/archive/20250310_105312_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 4...
# Synergy Prediction MSE on Known Edges: 1.5977
# Model loaded from: models/archive/20250310_105928_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 5...
# Synergy Prediction MSE on Known Edges: 1.1959
# Model loaded from: models/archive/20250310_110312_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 6...
# Synergy Prediction MSE on Known Edges: 1.7461
# Model loaded from: models/archive/20250310_110844_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 7...
# Synergy Prediction MSE on Known Edges: 1.5576
# Model loaded from: models/archive/20250310_111152_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 8...
# Synergy Prediction MSE on Known Edges: 1.6021
# Model loaded from: models/archive/20250310_111730_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 9...
# Synergy Prediction MSE on Known Edges: 0.9147
# Model loaded from: models/archive/20250310_112328_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 10...
# Synergy Prediction MSE on Known Edges: 1.7748
# Model loaded from: models/archive/20250310_112748_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 11...
# Synergy Prediction MSE on Known Edges: 1.5991
# Model loaded from: models/archive/20250310_113235_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 12...
# Synergy Prediction MSE on Known Edges: 1.0068
# Model loaded from: models/archive/20250310_113852_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 13...
# Synergy Prediction MSE on Known Edges: 2.1131
# Model loaded from: models/archive/20250310_114537_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 14...
# Synergy Prediction MSE on Known Edges: 1.5946
# Model loaded from: models/archive/20250310_114905_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 15...
# Synergy Prediction MSE on Known Edges: 2.1262
# Model loaded from: models/archive/20250310_115601_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 16...
# Synergy Prediction MSE on Known Edges: 1.5712
# Model loaded from: models/archive/20250310_120249_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 17...
# Synergy Prediction MSE on Known Edges: 2.1055
# Model loaded from: models/archive/20250310_120930_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 18...
# Synergy Prediction MSE on Known Edges: 1.9912
# Model loaded from: models/archive/20250310_121534_gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 19...
# Synergy Prediction MSE on Known Edges: 2.1153
# Model loaded from: models/gnn_model_ST02-001.pth
# Calculating synergy for leader ST02-001, trial 20...
# Synergy Prediction MSE on Known Edges: 1.5957
# Model loaded from: models/archive/20250310_124906_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 1...
# Synergy Prediction MSE on Known Edges: 1.6853
# Model loaded from: models/archive/20250310_130357_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 2...
# Synergy Prediction MSE on Known Edges: 1.1332
# Model loaded from: models/archive/20250310_131251_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 3...
# Synergy Prediction MSE on Known Edges: 1.4794
# Model loaded from: models/archive/20250310_132633_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 4...
# Synergy Prediction MSE on Known Edges: 1.2654
# Model loaded from: models/archive/20250310_134640_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 5...
# Synergy Prediction MSE on Known Edges: 1.5693
# Model loaded from: models/archive/20250310_140535_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 6...
# Synergy Prediction MSE on Known Edges: 1.6440
# Model loaded from: models/archive/20250310_142354_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 7...
# Synergy Prediction MSE on Known Edges: 1.1204
# Model loaded from: models/archive/20250310_144243_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 8...
# Synergy Prediction MSE on Known Edges: 2.6409
# Model loaded from: models/archive/20250310_150000_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 9...
# Synergy Prediction MSE on Known Edges: 1.5511
# Model loaded from: models/archive/20250310_151659_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 10...
# Synergy Prediction MSE on Known Edges: 1.3838
# Model loaded from: models/archive/20250310_153450_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 11...
# Synergy Prediction MSE on Known Edges: 1.6966
# Model loaded from: models/archive/20250310_155124_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 12...
# Synergy Prediction MSE on Known Edges: 1.4454
# Model loaded from: models/archive/20250310_160222_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 13...
# Synergy Prediction MSE on Known Edges: 1.4119
# Model loaded from: models/archive/20250310_161823_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 14...
# Synergy Prediction MSE on Known Edges: 0.8315
# Model loaded from: models/archive/20250310_162924_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 15...
# Synergy Prediction MSE on Known Edges: 1.4242
# Model loaded from: models/archive/20250310_163821_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 16...
# Synergy Prediction MSE on Known Edges: 1.4674
# Model loaded from: models/archive/20250310_164728_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 17...
# Synergy Prediction MSE on Known Edges: 1.1628
# Model loaded from: models/archive/20250310_170323_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 18...
# Synergy Prediction MSE on Known Edges: 1.3983
# Model loaded from: models/archive/20250310_171913_gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 19...
# Synergy Prediction MSE on Known Edges: 1.3825
# Model loaded from: models/gnn_model_ST13-003.pth
# Calculating synergy for leader ST13-003, trial 20...
# Synergy Prediction MSE on Known Edges: 1.4659
# Correlation synergy_mse <-> score (all leaders): 0.348
# Leader OP01-001: corr(synergy_mse, score)=-0.094
# Leader OP07-079: corr(synergy_mse, score)=0.724
# Leader OP08-098: corr(synergy_mse, score)=0.797
# Leader ST02-001: corr(synergy_mse, score)=0.829
# Leader ST13-003: corr(synergy_mse, score)=-0.385

# %%
# optional: load from csv into pandas
df_final_temp = pd.read_csv("evaluations/df_final_temp.csv")
df_final_temp.head()
# Out:
#      leader  gnn_trial  deck_trial        score  meta_overlap  avg_synergy  \
# 0  OP01-001          1           1  2853.559082             0     2.063501
# 1  OP01-001          1           2  2815.091309             1     2.047359
# 2  OP01-001          1           3  2837.621826             1     2.053221
# 3  OP01-001          1           4  2853.666748             1     2.061460
# 4  OP01-001          1           5  2840.410645             3     2.057597
#
#    num_singletons  deck_size  synergy_mse
# 0               5         50       1.7926
# 1               5         50       1.7926
# 2               5         50       1.7926
# 3               5         50       1.7926
# 4               5         50       1.7926

# %%
if not df_final.empty:
    # Boxplot synergy_mse pro Leader
    plt.figure(figsize=(8,5))
    df_final.boxplot(column="synergy_mse", by="leader")
    plt.title("Synergy-MSE pro Leader (alle Trials & Decks)")
    plt.suptitle("")
    plt.ylabel("MSE (Synergy)")
    plt.show()
else:
    print("df_final ist leer; keine Daten zusammengeführt.")

# %%
print(f"Final merged shape: {df_final.shape}")
df_final.head()
# Out:
# Final merged shape: (25000, 9)
#      leader  gnn_trial  deck_trial        score  meta_overlap  avg_synergy  \
# 0  OP01-001          1           1  2853.559082             0     2.063501
# 1  OP01-001          1           2  2815.091309             1     2.047359
# 2  OP01-001          1           3  2837.621826             1     2.053221
# 3  OP01-001          1           4  2853.666748             1     2.061460
# 4  OP01-001          1           5  2840.410645             3     2.057597
#
#    num_singletons  deck_size  synergy_mse
# 0               5         50     1.792633
# 1               5         50     1.792633
# 2               5         50     1.792633
# 3               5         50     1.792633
# 4               5         50     1.792633
